# %%
import pandas as pd
from datetime import datetime, timedelta

# %%
config = {
    "comedy": {
        "path": "source_data/kenji/pupil_size_extracted_comedy.csv",
        "start_time": datetime.strptime("2025-06-05 16:25:43", "%Y-%m-%d %H:%M:%S")
    },
    "documentary": {
        "path": "source_data/kenji/pupil_size_extracted_documentary.csv",
        "start_time": datetime.strptime("2025-06-05 17:13:12", "%Y-%m-%d %H:%M:%S")
    },
    "horror": {
        "path": "source_data/kenji/pupil_size_extracted_horror.csv",
        "start_time": datetime.strptime("2025-06-05 17:58:47", "%Y-%m-%d %H:%M:%S")
    },
}

# %%
comedy = pd.read_csv(config["comedy"]["path"])
documentary = pd.read_csv(config["documentary"]["path"])
horror = pd.read_csv(config["horror"]["path"])

comedy
# Out:
#       success  pupil_diameter_mm  iris_diameter_mm  pupil_iris_ratio  \
# 0        True                0.0              11.8               0.0
# 1        True                0.0              11.8               0.0
# 2        True                0.0              11.8               0.0
# 3        True                0.0              11.8               0.0
# 4        True                0.0              11.8               0.0
# ...       ...                ...               ...               ...
# 3679     True                0.0              11.8               0.0
# 3680     True                0.0              11.8               0.0
# 3681     True                0.0              11.8               0.0
# 3682     True                0.0              11.8               0.0
# 3683     True                0.0              11.8               0.0
#
#      gaze_direction  overall_confidence pupil_classification  pupil_detected  \
# 0            Center            0.352557              Unknown            True
# 1            Center            0.291673              Unknown            True
# 2            Center            0.269764              Unknown            True
# 3            Center            0.343532              Unknown            True
# 4            Center            0.380328              Unknown            True
# ...             ...                 ...                  ...             ...
# 3679         Center            0.263127              Unknown            True
# 3680         Center            0.335181              Unknown            True
# 3681         Center            0.478930              Unknown            True
# 3682         Center            0.329396              Unknown            True
# 3683         Center            0.325944              Unknown            True
#
#       iris_detected  pupil_center_x  pupil_center_y  iris_center_x  \
# 0             False             216               7              0
# 1             False              37              18              0
# 2             False             119              42              0
# 3             False             135             113              0
# 4             False             178             129              0
# ...             ...             ...             ...            ...
# 3679          False              60             127              0
# 3680          False             145             107              0
# 3681          False               7             101              0
# 3682          False               4             133              0
# 3683          False             136             116              0
#
#       iris_center_y  gaze_magnitude  concentricity_score  pupil_circularity  \
# 0                 0             0.0                  0.0           0.470076
# 1                 0             0.0                  0.0           0.388897
# 2                 0             0.0                  0.0           0.359685
# 3                 0             0.0                  0.0           0.458043
# 4                 0             0.0                  0.0           0.507104
# ...             ...             ...                  ...                ...
# 3679              0             0.0                  0.0           0.350836
# 3680              0             0.0                  0.0           0.446908
# 3681              0             0.0                  0.0           0.638574
# 3682              0             0.0                  0.0           0.439195
# 3683              0             0.0                  0.0           0.434592
#
#       timestamp
# 0        1504.0
# 1        1255.0
# 2         873.5
# 3         599.0
# 4         973.5
# ...         ...
# 3679      672.0
# 3680      123.0
# 3681     1309.0
# 3682     1458.0
# 3683      394.0
#
# [3684 rows x 17 columns]

# %%
# drop useless rows 
def clean_rows(df_to_clean):
    return df_to_clean[df_to_clean['success'] == True]

comedy = clean_rows(comedy)
documentary = clean_rows(documentary)
horror = clean_rows(horror)

print(set(comedy.success))
print(set(documentary.success))
print(set(horror.success))
# Out:
# {True}
# {True}
# {True}

# %%
columns_to_drop = ['success', 'pupil_classification', 'pupil_center_x', 'pupil_center_y', 'iris_center_x', 'iris_center_y', 'gaze_magnitude', 'concentricity_score']

comedy.drop(columns=columns_to_drop, inplace=True)
documentary.drop(columns=columns_to_drop, inplace=True)
horror.drop(columns=columns_to_drop, inplace=True)

# %%
comedy
# Out:
#       pupil_diameter_mm  iris_diameter_mm  pupil_iris_ratio gaze_direction  \
# 0                   0.0              11.8               0.0         Center
# 1                   0.0              11.8               0.0         Center
# 2                   0.0              11.8               0.0         Center
# 3                   0.0              11.8               0.0         Center
# 4                   0.0              11.8               0.0         Center
# ...                 ...               ...               ...            ...
# 3679                0.0              11.8               0.0         Center
# 3680                0.0              11.8               0.0         Center
# 3681                0.0              11.8               0.0         Center
# 3682                0.0              11.8               0.0         Center
# 3683                0.0              11.8               0.0         Center
#
#       overall_confidence  pupil_detected  iris_detected  pupil_circularity  \
# 0               0.352557            True          False           0.470076
# 1               0.291673            True          False           0.388897
# 2               0.269764            True          False           0.359685
# 3               0.343532            True          False           0.458043
# 4               0.380328            True          False           0.507104
# ...                  ...             ...            ...                ...
# 3679            0.263127            True          False           0.350836
# 3680            0.335181            True          False           0.446908
# 3681            0.478930            True          False           0.638574
# 3682            0.329396            True          False           0.439195
# 3683            0.325944            True          False           0.434592
#
#       timestamp
# 0        1504.0
# 1        1255.0
# 2         873.5
# 3         599.0
# 4         973.5
# ...         ...
# 3679      672.0
# 3680      123.0
# 3681     1309.0
# 3682     1458.0
# 3683      394.0
#
# [3684 rows x 9 columns]

# %%
# Convert timestamp (float seconds) to actual datetime
comedy['time'] = comedy['timestamp'].apply(lambda x: config["comedy"]["start_time"] + timedelta(seconds=x))
documentary['time'] = documentary['timestamp'].apply(lambda x: config["documentary"]["start_time"] + timedelta(seconds=x))
horror['time'] = horror['timestamp'].apply(lambda x: config["horror"]["start_time"] + timedelta(seconds=x))

comedy
# Out:
#       pupil_diameter_mm  iris_diameter_mm  pupil_iris_ratio gaze_direction  \
# 0                   0.0              11.8               0.0         Center
# 1                   0.0              11.8               0.0         Center
# 2                   0.0              11.8               0.0         Center
# 3                   0.0              11.8               0.0         Center
# 4                   0.0              11.8               0.0         Center
# ...                 ...               ...               ...            ...
# 3679                0.0              11.8               0.0         Center
# 3680                0.0              11.8               0.0         Center
# 3681                0.0              11.8               0.0         Center
# 3682                0.0              11.8               0.0         Center
# 3683                0.0              11.8               0.0         Center
#
#       overall_confidence  pupil_detected  iris_detected  pupil_circularity  \
# 0               0.352557            True          False           0.470076
# 1               0.291673            True          False           0.388897
# 2               0.269764            True          False           0.359685
# 3               0.343532            True          False           0.458043
# 4               0.380328            True          False           0.507104
# ...                  ...             ...            ...                ...
# 3679            0.263127            True          False           0.350836
# 3680            0.335181            True          False           0.446908
# 3681            0.478930            True          False           0.638574
# 3682            0.329396            True          False           0.439195
# 3683            0.325944            True          False           0.434592
#
#       timestamp                    time
# 0        1504.0 2025-06-05 16:50:47.000
# 1        1255.0 2025-06-05 16:46:38.000
# 2         873.5 2025-06-05 16:40:16.500
# 3         599.0 2025-06-05 16:35:42.000
# 4         973.5 2025-06-05 16:41:56.500
# ...         ...                     ...
# 3679      672.0 2025-06-05 16:36:55.000
# 3680      123.0 2025-06-05 16:27:46.000
# 3681     1309.0 2025-06-05 16:47:32.000
# 3682     1458.0 2025-06-05 16:50:01.000
# 3683      394.0 2025-06-05 16:32:17.000
#
# [3684 rows x 10 columns]

# %%
def reset_timestamp_column(df_to_reset):
    df_to_reset = df_to_reset.sort_values(by='time').reset_index(drop=True)
    df_to_reset['timestamp'] = df_to_reset['time'] 
    df_to_reset.drop(columns=['time'], inplace=True)
    return df_to_reset

comedy = reset_timestamp_column(comedy)
documentary = reset_timestamp_column(documentary)
horror = reset_timestamp_column(horror)

# %%
# comedy = comedy.set_index('timestamp')
# documentary = documentary.set_index('timestamp')
# horror = horror.set_index('timestamp')

# %%
comedy
# Out:
#       pupil_diameter_mm  iris_diameter_mm  pupil_iris_ratio gaze_direction  \
# 0                   0.0              11.8               0.0         Center
# 1                   0.0              11.8               0.0         Center
# 2                   0.0              11.8               0.0         Center
# 3                   0.0              11.8               0.0         Center
# 4                   0.0              11.8               0.0         Center
# ...                 ...               ...               ...            ...
# 3679                0.0              11.8               0.0         Center
# 3680                0.0              11.8               0.0         Center
# 3681                0.0              11.8               0.0         Center
# 3682                0.0              11.8               0.0         Center
# 3683                0.0              11.8               0.0         Center
#
#       overall_confidence  pupil_detected  iris_detected  pupil_circularity  \
# 0               0.458089            True          False           0.610785
# 1               0.337658            True          False           0.450210
# 2               0.299254            True          False           0.399006
# 3               0.346880            True          False           0.462506
# 4               0.354830            True          False           0.473107
# ...                  ...             ...            ...                ...
# 3679            0.349275            True          False           0.465700
# 3680            0.317610            True          False           0.423480
# 3681            0.243363            True          False           0.324484
# 3682            0.500000            True          False           0.690612
# 3683            0.266303            True          False           0.355070
#
#                    timestamp
# 0    2025-06-05 16:25:43.000
# 1    2025-06-05 16:25:43.500
# 2    2025-06-05 16:25:44.000
# 3    2025-06-05 16:25:44.500
# 4    2025-06-05 16:25:45.000
# ...                      ...
# 3679 2025-06-05 16:56:22.500
# 3680 2025-06-05 16:56:23.000
# 3681 2025-06-05 16:56:23.500
# 3682 2025-06-05 16:56:24.000
# 3683 2025-06-05 16:56:24.500
#
# [3684 rows x 9 columns]

# %%
numeric_cols = ['pupil_diameter_mm', 'iris_diameter_mm', 'pupil_iris_ratio', 'overall_confidence','pupil_circularity', 'timestamp']
non_numeric_cols = ['gaze_direction', 'pupil_detected', 'iris_detected']

def aggregate_data(df_to_aggregate):
    df_to_aggregate['timestamp'] = pd.to_datetime(df_to_aggregate['timestamp']).dt.tz_localize(None)
    df_to_aggregate['time_rounded'] = df_to_aggregate['timestamp'].dt.floor('1s')
    

    # Function to apply to each group
    def agg_group(group):
        numeric_part = group[numeric_cols].mean()
        best_row = group.loc[group['overall_confidence'].idxmax(), non_numeric_cols]
        return pd.concat([numeric_part, best_row])

    aggregated = df_to_aggregate.groupby('time_rounded').apply(agg_group).reset_index()
    return aggregated

# %%
comedy_agg = aggregate_data(comedy)
documentary_agg = aggregate_data(documentary)
horror_agg = aggregate_data(horror)
# Out:
# /var/folders/9p/62h9vn7x3d3cx_q5nl10qry00000gn/T/ipykernel_63751/734002556.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   aggregated = df_to_aggregate.groupby('time_rounded').apply(agg_group).reset_index()
# /var/folders/9p/62h9vn7x3d3cx_q5nl10qry00000gn/T/ipykernel_63751/734002556.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   aggregated = df_to_aggregate.groupby('time_rounded').apply(agg_group).reset_index()
# /var/folders/9p/62h9vn7x3d3cx_q5nl10qry00000gn/T/ipykernel_63751/734002556.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   aggregated = df_to_aggregate.groupby('time_rounded').apply(agg_group).reset_index()

# %%
comedy_agg
# Out:
#             time_rounded  pupil_diameter_mm  iris_diameter_mm  \
# 0    2025-06-05 16:25:43                0.0              11.8
# 1    2025-06-05 16:25:44                0.0              11.8
# 2    2025-06-05 16:25:45                0.0              11.8
# 3    2025-06-05 16:25:46                0.0              11.8
# 4    2025-06-05 16:25:47                0.0              11.8
# ...                  ...                ...               ...
# 1837 2025-06-05 16:56:20                0.0              11.8
# 1838 2025-06-05 16:56:21                0.0              11.8
# 1839 2025-06-05 16:56:22                0.0              11.8
# 1840 2025-06-05 16:56:23                0.0              11.8
# 1841 2025-06-05 16:56:24                0.0              11.8
#
#       pupil_iris_ratio  overall_confidence  pupil_circularity  \
# 0                  0.0            0.397873           0.530498
# 1                  0.0            0.323067           0.430756
# 2                  0.0            0.319347           0.425796
# 3                  0.0            0.258393           0.344524
# 4                  0.0            0.320713           0.427618
# ...                ...                 ...                ...
# 1837               0.0            0.248906           0.331875
# 1838               0.0            0.283869           0.378492
# 1839               0.0            0.326627           0.435503
# 1840               0.0            0.280486           0.373982
# 1841               0.0            0.383151           0.522841
#
#                          timestamp gaze_direction  pupil_detected  \
# 0    2025-06-05 16:25:43.249999872         Center            True
# 1    2025-06-05 16:25:44.249999872         Center            True
# 2    2025-06-05 16:25:45.249999872         Center            True
# 3    2025-06-05 16:25:46.249999872         Center            True
# 4    2025-06-05 16:25:47.249999872         Center            True
# ...                            ...            ...             ...
# 1837 2025-06-05 16:56:20.249999872         Center            True
# 1838 2025-06-05 16:56:21.249999872         Center            True
# 1839 2025-06-05 16:56:22.249999872         Center            True
# 1840 2025-06-05 16:56:23.249999872         Center            True
# 1841 2025-06-05 16:56:24.249999872         Center            True
#
#       iris_detected
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ...             ...
# 1837          False
# 1838          False
# 1839          False
# 1840          False
# 1841          False
#
# [1842 rows x 10 columns]

# %%
comedy_agg.drop(columns=['timestamp'], inplace=True)
documentary_agg.drop(columns=['timestamp'], inplace=True)
horror_agg.drop(columns=['timestamp'], inplace=True)

comedy_agg['timestamp'] = comedy_agg['time_rounded']
documentary_agg['timestamp'] = documentary_agg['time_rounded']
horror_agg['timestamp'] = horror_agg['time_rounded']

comedy_agg.drop(columns=['time_rounded'], inplace=True)
documentary_agg.drop(columns=['time_rounded'], inplace=True)
horror_agg.drop(columns=['time_rounded'], inplace=True)

# %%
comedy_agg.set_index('timestamp', inplace=True)
documentary_agg.set_index('timestamp', inplace=True)
horror_agg.set_index('timestamp', inplace=True)

# %%
comedy_agg
# Out:
#                      pupil_diameter_mm  iris_diameter_mm  pupil_iris_ratio  \
# timestamp
# 2025-06-05 16:25:43                0.0              11.8               0.0
# 2025-06-05 16:25:44                0.0              11.8               0.0
# 2025-06-05 16:25:45                0.0              11.8               0.0
# 2025-06-05 16:25:46                0.0              11.8               0.0
# 2025-06-05 16:25:47                0.0              11.8               0.0
# ...                                ...               ...               ...
# 2025-06-05 16:56:20                0.0              11.8               0.0
# 2025-06-05 16:56:21                0.0              11.8               0.0
# 2025-06-05 16:56:22                0.0              11.8               0.0
# 2025-06-05 16:56:23                0.0              11.8               0.0
# 2025-06-05 16:56:24                0.0              11.8               0.0
#
#                      overall_confidence  pupil_circularity gaze_direction  \
# timestamp
# 2025-06-05 16:25:43            0.397873           0.530498         Center
# 2025-06-05 16:25:44            0.323067           0.430756         Center
# 2025-06-05 16:25:45            0.319347           0.425796         Center
# 2025-06-05 16:25:46            0.258393           0.344524         Center
# 2025-06-05 16:25:47            0.320713           0.427618         Center
# ...                                 ...                ...            ...
# 2025-06-05 16:56:20            0.248906           0.331875         Center
# 2025-06-05 16:56:21            0.283869           0.378492         Center
# 2025-06-05 16:56:22            0.326627           0.435503         Center
# 2025-06-05 16:56:23            0.280486           0.373982         Center
# 2025-06-05 16:56:24            0.383151           0.522841         Center
#
#                      pupil_detected  iris_detected
# timestamp
# 2025-06-05 16:25:43            True          False
# 2025-06-05 16:25:44            True          False
# 2025-06-05 16:25:45            True          False
# 2025-06-05 16:25:46            True          False
# 2025-06-05 16:25:47            True          False
# ...                             ...            ...
# 2025-06-05 16:56:20            True          False
# 2025-06-05 16:56:21            True          False
# 2025-06-05 16:56:22            True          False
# 2025-06-05 16:56:23            True          False
# 2025-06-05 16:56:24            True          False
#
# [1842 rows x 8 columns]

# %%
documentary_agg
# Out:
#                      pupil_diameter_mm  iris_diameter_mm  pupil_iris_ratio  \
# timestamp
# 2025-06-05 17:13:12           0.000000              11.8          0.000000
# 2025-06-05 17:13:13           0.000000              11.8          0.000000
# 2025-06-05 17:13:14           0.000000              11.8          0.000000
# 2025-06-05 17:13:15           0.000000              11.8          0.000000
# 2025-06-05 17:13:16           0.000000              11.8          0.000000
# ...                                ...               ...               ...
# 2025-06-05 17:44:06           0.000000              11.8          0.000000
# 2025-06-05 17:44:07           0.000000              11.8          0.000000
# 2025-06-05 17:44:08           0.000000              11.8          0.000000
# 2025-06-05 17:44:09           0.000000              11.8          0.000000
# 2025-06-05 17:44:10           1.229167              11.8          0.104167
#
#                      overall_confidence  pupil_circularity gaze_direction  \
# timestamp
# 2025-06-05 17:13:12            0.280724           0.374299         Center
# 2025-06-05 17:13:13            0.334065           0.445420         Center
# 2025-06-05 17:13:14            0.289081           0.385442         Center
# 2025-06-05 17:13:15            0.373520           0.498027         Center
# 2025-06-05 17:13:16            0.323767           0.431690         Center
# ...                                 ...                ...            ...
# 2025-06-05 17:44:06            0.310843           0.414457         Center
# 2025-06-05 17:44:07            0.345671           0.460895         Center
# 2025-06-05 17:44:08            0.262832           0.350442         Center
# 2025-06-05 17:44:09            0.253057           0.337409         Center
# 2025-06-05 17:44:10            0.382587           0.351414     Down-Right
#
#                      pupil_detected  iris_detected
# timestamp
# 2025-06-05 17:13:12            True          False
# 2025-06-05 17:13:13            True          False
# 2025-06-05 17:13:14            True          False
# 2025-06-05 17:13:15            True          False
# 2025-06-05 17:13:16            True          False
# ...                             ...            ...
# 2025-06-05 17:44:06            True          False
# 2025-06-05 17:44:07            True          False
# 2025-06-05 17:44:08            True          False
# 2025-06-05 17:44:09            True          False
# 2025-06-05 17:44:10            True           True
#
# [1859 rows x 8 columns]

# %%
horror_agg
# Out:
#                      pupil_diameter_mm  iris_diameter_mm  pupil_iris_ratio  \
# timestamp
# 2025-06-05 17:58:47                0.0              11.8               0.0
# 2025-06-05 17:58:48                0.0              11.8               0.0
# 2025-06-05 17:58:49                0.0              11.8               0.0
# 2025-06-05 17:58:50                0.0              11.8               0.0
# 2025-06-05 17:58:51                0.0              11.8               0.0
# ...                                ...               ...               ...
# 2025-06-05 18:27:15                0.0              11.8               0.0
# 2025-06-05 18:27:16                0.0              11.8               0.0
# 2025-06-05 18:27:17                0.0              11.8               0.0
# 2025-06-05 18:27:18                0.0              11.8               0.0
# 2025-06-05 18:27:19                0.0              11.8               0.0
#
#                      overall_confidence  pupil_circularity gaze_direction  \
# timestamp
# 2025-06-05 17:58:47            0.341908           0.455878         Center
# 2025-06-05 17:58:48            0.349734           0.466312         Center
# 2025-06-05 17:58:49            0.389688           0.528438         Center
# 2025-06-05 17:58:50            0.463993           0.618657         Center
# 2025-06-05 17:58:51            0.429819           0.573093         Center
# ...                                 ...                ...            ...
# 2025-06-05 18:27:15            0.334241           0.445655         Center
# 2025-06-05 18:27:16            0.312355           0.416473         Center
# 2025-06-05 18:27:17            0.366722           0.488962         Center
# 2025-06-05 18:27:18            0.345114           0.460152         Center
# 2025-06-05 18:27:19            0.387111           0.523395         Center
#
#                      pupil_detected  iris_detected
# timestamp
# 2025-06-05 17:58:47            True          False
# 2025-06-05 17:58:48            True          False
# 2025-06-05 17:58:49            True          False
# 2025-06-05 17:58:50            True          False
# 2025-06-05 17:58:51            True          False
# ...                             ...            ...
# 2025-06-05 18:27:15            True          False
# 2025-06-05 18:27:16            True          False
# 2025-06-05 18:27:17            True          False
# 2025-06-05 18:27:18            True          False
# 2025-06-05 18:27:19            True          False
#
# [1713 rows x 8 columns]

# %%
comedy_agg.to_csv('../data_collection/generated_data/comedy_ps.csv')
documentary_agg.to_csv('../data_collection/generated_data/documentary_ps.csv')
horror_agg.to_csv('../data_collection/generated_data/horror_ps.csv')
