# %%
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
# load apple watch data
comedy_aw = pd.read_csv('generated_data/comedy_aw.csv')
documentary_aw = pd.read_csv('generated_data/documentary_aw.csv')
horror_aw = pd.read_csv('generated_data/horror_aw.csv')

# load tracked motion data
comedy_tm = pd.read_csv('generated_data/comedy_tm.csv')
documentary_tm = pd.read_csv('generated_data/documentary_tm.csv')
horror_tm = pd.read_csv('generated_data/horror_tm.csv')

# load pupil size data
comedy_ps = pd.read_csv('generated_data/comedy_ps.csv')
documentary_ps = pd.read_csv('generated_data/documentary_ps.csv')
horror_ps = pd.read_csv('generated_data/horror_ps.csv')

# %%
def merge_dataframes(aw_df, tm_df, ps_df):
    # Convert to datetime
    aw_df['timestamp'] = pd.to_datetime(aw_df['timestamp']).dt.tz_localize(None)
    tm_df['timestamp'] = pd.to_datetime(tm_df['timestamp']).dt.tz_localize(None)
    ps_df['timestamp'] = pd.to_datetime(ps_df['timestamp']).dt.tz_localize(None)
    
    # Sort all DataFrames 
    aw = aw_df.sort_values('timestamp')
    tm = tm_df.sort_values('timestamp')
    ps = ps_df.sort_values('timestamp')
    
    # Merge on nearest time
    merged = pd.merge(aw, tm, on='timestamp', how='inner')
    return pd.merge(merged, ps, on='timestamp', how='inner')

# %%
comedy = merge_dataframes(comedy_aw, comedy_tm, comedy_ps)
documentary = merge_dataframes(documentary_aw, documentary_tm, documentary_ps)
horror = merge_dataframes(horror_aw, horror_tm, horror_ps)

# %%
comedy
# Out:
#               timestamp  active_energy_burned  basal_energy_burned  \
# 0   2025-06-05 16:25:55                   NaN                  NaN
# 1   2025-06-05 16:25:56                 0.077                0.066
# 2   2025-06-05 16:25:59                 0.077                0.066
# 3   2025-06-05 16:26:01                 0.077                0.066
# 4   2025-06-05 16:26:04                 0.077                0.066
# ..                  ...                   ...                  ...
# 945 2025-06-05 16:56:13                 0.077                0.066
# 946 2025-06-05 16:56:15                 0.077                0.066
# 947 2025-06-05 16:56:18                 0.077                0.066
# 948 2025-06-05 16:56:20                 0.077                0.066
# 949 2025-06-05 16:56:23                 0.129                0.066
#
#      heart_rate  physical_effort  x_coordinate  y_coordinate  \
# 0          62.0              NaN    409.206897    194.000000
# 1           NaN              NaN    413.433333    194.800000
# 2          60.0              NaN    397.333333    191.000000
# 3           NaN              NaN    397.166667    190.600000
# 4           NaN              NaN    391.000000    189.333333
# ..          ...              ...           ...           ...
# 945        62.0              NaN    335.866667    207.000000
# 946         NaN              NaN    348.233333    203.666667
# 947        67.0              NaN    344.033333    205.866667
# 948         NaN              6.5    345.866667    205.033333
# 949         NaN              NaN    347.933333    201.066667
#
#      pupil_diameter_mm  iris_diameter_mm  pupil_iris_ratio  \
# 0             0.000000              11.8          0.000000
# 1             0.000000              11.8          0.000000
# 2             0.000000              11.8          0.000000
# 3             0.000000              11.8          0.000000
# 4             2.602941              11.8          0.220588
# ..                 ...               ...               ...
# 945           0.000000              11.8          0.000000
# 946           0.000000              11.8          0.000000
# 947           0.000000              11.8          0.000000
# 948           0.000000              11.8          0.000000
# 949           0.000000              11.8          0.000000
#
#      overall_confidence  pupil_circularity gaze_direction  pupil_detected  \
# 0              0.463664           0.649469         Center            True
# 1              0.464653           0.619537         Center            True
# 2              0.253074           0.337432         Center            True
# 3              0.272663           0.363550         Center            True
# 4              0.413849           0.392842       Up-Right            True
# ..                  ...                ...            ...             ...
# 945            0.497016           0.710121         Center            True
# 946            0.360245           0.480327         Center            True
# 947            0.385128           0.513503         Center            True
# 948            0.248906           0.331875         Center            True
# 949            0.280486           0.373982         Center            True
#
#      iris_detected
# 0            False
# 1            False
# 2            False
# 3            False
# 4             True
# ..             ...
# 945          False
# 946          False
# 947          False
# 948          False
# 949          False
#
# [950 rows x 15 columns]

# %%
documentary
# Out:
#               timestamp  active_energy_burned  basal_energy_burned  \
# 0   2025-06-05 17:13:30                 0.077                0.066
# 1   2025-06-05 17:13:33                 0.097                0.066
# 2   2025-06-05 17:13:35                 0.097                0.066
# 3   2025-06-05 17:13:38                 0.097                0.066
# 4   2025-06-05 17:13:40                 0.097                0.066
# ..                  ...                   ...                  ...
# 951 2025-06-05 17:43:59                 0.077                0.066
# 952 2025-06-05 17:44:02                 0.077                0.066
# 953 2025-06-05 17:44:05                 0.099                0.066
# 954 2025-06-05 17:44:07                 0.155                0.066
# 955 2025-06-05 17:44:10                 0.155                0.066
#
#      heart_rate  physical_effort  x_coordinate  y_coordinate  \
# 0          60.0              NaN    355.533333    225.700000
# 1          60.0              5.4    360.933333    223.600000
# 2           NaN              NaN    350.700000    222.400000
# 3           NaN              NaN    344.766667    225.600000
# 4          59.0              NaN    347.758621    228.000000
# ..          ...              ...           ...           ...
# 951        57.0              NaN    342.800000    269.766667
# 952        60.0              6.5    359.933333    279.433333
# 953         NaN              NaN    360.258065    283.580645
# 954         NaN              NaN    361.233333    283.233333
# 955        73.0              2.5    360.000000    284.000000
#
#      pupil_diameter_mm  iris_diameter_mm  pupil_iris_ratio  \
# 0             0.000000              11.8          0.000000
# 1             0.000000              11.8          0.000000
# 2             0.000000              11.8          0.000000
# 3             0.000000              11.8          0.000000
# 4             0.000000              11.8          0.000000
# ..                 ...               ...               ...
# 951           0.000000              11.8          0.000000
# 952           0.000000              11.8          0.000000
# 953           1.198438              11.8          0.101562
# 954           0.000000              11.8          0.000000
# 955           1.229167              11.8          0.104167
#
#      overall_confidence  pupil_circularity gaze_direction  pupil_detected  \
# 0              0.248222           0.330963         Center            True
# 1              0.309581           0.412775         Center            True
# 2              0.363035           0.484047         Center            True
# 3              0.327034           0.436045         Center            True
# 4              0.333728           0.444971         Center            True
# ..                  ...                ...            ...             ...
# 951            0.282593           0.376791         Center            True
# 952            0.295276           0.393701         Center            True
# 953            0.470213           0.458448          Right            True
# 954            0.345671           0.460895         Center            True
# 955            0.382587           0.351414     Down-Right            True
#
#      iris_detected
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ..             ...
# 951          False
# 952          False
# 953           True
# 954          False
# 955           True
#
# [956 rows x 15 columns]

# %%
horror
# Out:
#               timestamp  active_energy_burned  basal_energy_burned  \
# 0   2025-06-05 17:58:54                 0.077                0.066
# 1   2025-06-05 17:58:56                 0.077                0.066
# 2   2025-06-05 17:58:59                 0.077                0.066
# 3   2025-06-05 17:59:00                   NaN                  NaN
# 4   2025-06-05 17:59:01                 0.077                0.066
# ..                  ...                   ...                  ...
# 875 2025-06-05 18:27:09                 0.077                0.066
# 876 2025-06-05 18:27:12                 0.077                0.066
# 877 2025-06-05 18:27:15                 0.070                0.066
# 878 2025-06-05 18:27:16                   NaN                  NaN
# 879 2025-06-05 18:27:17                 0.070                0.066
#
#      heart_rate  physical_effort  x_coordinate  y_coordinate  \
# 0          56.0              NaN    374.935484    244.000000
# 1           NaN              NaN    371.965517    243.000000
# 2           NaN              NaN    366.620690    236.068966
# 3          54.0              NaN    359.833333    239.500000
# 4           NaN              NaN    359.433333    239.000000
# ..          ...              ...           ...           ...
# 875        56.0              NaN    303.400000    225.000000
# 876         NaN              NaN    302.866667    225.000000
# 877         NaN              NaN    302.833333    225.466667
# 878        53.0              NaN    302.533333    225.200000
# 879         NaN              5.0    303.000000    225.000000
#
#      pupil_diameter_mm  iris_diameter_mm  pupil_iris_ratio  \
# 0                  0.0              11.8               0.0
# 1                  0.0              11.8               0.0
# 2                  0.0              11.8               0.0
# 3                  0.0              11.8               0.0
# 4                  0.0              11.8               0.0
# ..                 ...               ...               ...
# 875                0.0              11.8               0.0
# 876                0.0              11.8               0.0
# 877                0.0              11.8               0.0
# 878                0.0              11.8               0.0
# 879                0.0              11.8               0.0
#
#      overall_confidence  pupil_circularity gaze_direction  pupil_detected  \
# 0              0.317583           0.423444         Center            True
# 1              0.436879           0.582505         Center            True
# 2              0.430969           0.613296         Center            True
# 3              0.285978           0.381305         Center            True
# 4              0.254932           0.339909         Center            True
# ..                  ...                ...            ...             ...
# 875            0.366368           0.488491         Center            True
# 876            0.270445           0.360594         Center            True
# 877            0.334241           0.445655         Center            True
# 878            0.312355           0.416473         Center            True
# 879            0.366722           0.488962         Center            True
#
#      iris_detected
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ..             ...
# 875          False
# 876          False
# 877          False
# 878          False
# 879          False
#
# [880 rows x 15 columns]

# %%
# Add genre column
comedy['genre'] = 'comedy'
documentary['genre'] = 'documentary'
horror['genre'] = 'horror'

# Concatenate all
df_all = pd.concat([comedy, documentary, horror], ignore_index=True)

# %%
df_all
# Out:
#                timestamp  active_energy_burned  basal_energy_burned  \
# 0    2025-06-05 16:25:55                   NaN                  NaN
# 1    2025-06-05 16:25:56                 0.077                0.066
# 2    2025-06-05 16:25:59                 0.077                0.066
# 3    2025-06-05 16:26:01                 0.077                0.066
# 4    2025-06-05 16:26:04                 0.077                0.066
# ...                  ...                   ...                  ...
# 2781 2025-06-05 18:27:09                 0.077                0.066
# 2782 2025-06-05 18:27:12                 0.077                0.066
# 2783 2025-06-05 18:27:15                 0.070                0.066
# 2784 2025-06-05 18:27:16                   NaN                  NaN
# 2785 2025-06-05 18:27:17                 0.070                0.066
#
#       heart_rate  physical_effort  x_coordinate  y_coordinate  \
# 0           62.0              NaN    409.206897    194.000000
# 1            NaN              NaN    413.433333    194.800000
# 2           60.0              NaN    397.333333    191.000000
# 3            NaN              NaN    397.166667    190.600000
# 4            NaN              NaN    391.000000    189.333333
# ...          ...              ...           ...           ...
# 2781        56.0              NaN    303.400000    225.000000
# 2782         NaN              NaN    302.866667    225.000000
# 2783         NaN              NaN    302.833333    225.466667
# 2784        53.0              NaN    302.533333    225.200000
# 2785         NaN              5.0    303.000000    225.000000
#
#       pupil_diameter_mm  iris_diameter_mm  pupil_iris_ratio  \
# 0              0.000000              11.8          0.000000
# 1              0.000000              11.8          0.000000
# 2              0.000000              11.8          0.000000
# 3              0.000000              11.8          0.000000
# 4              2.602941              11.8          0.220588
# ...                 ...               ...               ...
# 2781           0.000000              11.8          0.000000
# 2782           0.000000              11.8          0.000000
# 2783           0.000000              11.8          0.000000
# 2784           0.000000              11.8          0.000000
# 2785           0.000000              11.8          0.000000
#
#       overall_confidence  pupil_circularity gaze_direction  pupil_detected  \
# 0               0.463664           0.649469         Center            True
# 1               0.464653           0.619537         Center            True
# 2               0.253074           0.337432         Center            True
# 3               0.272663           0.363550         Center            True
# 4               0.413849           0.392842       Up-Right            True
# ...                  ...                ...            ...             ...
# 2781            0.366368           0.488491         Center            True
# 2782            0.270445           0.360594         Center            True
# 2783            0.334241           0.445655         Center            True
# 2784            0.312355           0.416473         Center            True
# 2785            0.366722           0.488962         Center            True
#
#       iris_detected   genre
# 0             False  comedy
# 1             False  comedy
# 2             False  comedy
# 3             False  comedy
# 4              True  comedy
# ...             ...     ...
# 2781          False  horror
# 2782          False  horror
# 2783          False  horror
# 2784          False  horror
# 2785          False  horror
#
# [2786 rows x 16 columns]

# %%
df_all.to_csv('generated_data/all_genres.csv', index=False)
