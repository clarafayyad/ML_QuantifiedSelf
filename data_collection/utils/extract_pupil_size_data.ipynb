# %%
import pandas as pd
from datetime import datetime, timedelta

# %%
config = {
    "comedy": {
        "path": "../source_data/aimen/pupil_size_extracted_comedy.csv",
        "start_time": datetime.strptime("2025-06-12 09:46:46", "%Y-%m-%d %H:%M:%S")
    },
    "documentary": {
        "path": "../source_data/aimen/pupil_size_extracted_doc.csv",
        "start_time": datetime.strptime("2025-06-12 09:22:19", "%Y-%m-%d %H:%M:%S")
    },
    "horror": {
        "path": "../source_data/aimen/pupil_size_extracted_horror.csv",
        "start_time": datetime.strptime("2025-06-12 10:11:55", "%Y-%m-%d %H:%M:%S")
    },
}

# %%
comedy = pd.read_csv(config["comedy"]["path"])
documentary = pd.read_csv(config["documentary"]["path"])
horror = pd.read_csv(config["horror"]["path"])

comedy
# Out:
#       success  pupil_diameter_mm  iris_diameter_mm  pupil_iris_ratio  \
# 0        True                0.0              11.8               0.0
# 1        True                0.0              11.8               0.0
# 2        True                0.0              11.8               0.0
# 3        True                0.0              11.8               0.0
# 4        True                0.0              11.8               0.0
# ...       ...                ...               ...               ...
# 2564     True                0.0              11.8               0.0
# 2565     True                0.0              11.8               0.0
# 2566     True                0.0              11.8               0.0
# 2567     True                0.0              11.8               0.0
# 2568     True                0.0              11.8               0.0
#
#      gaze_direction  overall_confidence pupil_classification  pupil_detected  \
# 0            Center            0.312995              Unknown            True
# 1            Center            0.255435              Unknown            True
# 2            Center            0.226924              Unknown            True
# 3            Center            0.227541              Unknown            True
# 4            Center            0.329428              Unknown            True
# ...             ...                 ...                  ...             ...
# 2564         Center            0.298038              Unknown            True
# 2565         Center            0.358844              Unknown            True
# 2566         Center            0.366174              Unknown            True
# 2567         Center            0.336177              Unknown            True
# 2568         Center            0.382816              Unknown            True
#
#       iris_detected  pupil_center_x  pupil_center_y  iris_center_x  \
# 0             False              79             103              0
# 1             False              26             227              0
# 2             False             239              21              0
# 3             False               5              91              0
# 4             False               2             200              0
# ...             ...             ...             ...            ...
# 2564          False               8             125              0
# 2565          False             247              88              0
# 2566          False             247              88              0
# 2567          False               6              92              0
# 2568          False             248              89              0
#
#       iris_center_y  gaze_magnitude  concentricity_score  pupil_circularity  \
# 0                 0             0.0                  0.0           0.417327
# 1                 0             0.0                  0.0           0.340579
# 2                 0             0.0                  0.0           0.302566
# 3                 0             0.0                  0.0           0.303388
# 4                 0             0.0                  0.0           0.439237
# ...             ...             ...                  ...                ...
# 2564              0             0.0                  0.0           0.397384
# 2565              0             0.0                  0.0           0.478458
# 2566              0             0.0                  0.0           0.488232
# 2567              0             0.0                  0.0           0.448236
# 2568              0             0.0                  0.0           0.510422
#
#       timestamp
# 0           0.0
# 1           0.5
# 2           1.0
# 3           1.5
# 4          10.0
# ...         ...
# 2564      997.5
# 2565      998.0
# 2566      998.5
# 2567      999.0
# 2568      999.5
#
# [2569 rows x 17 columns]

# %%
# drop useless rows 
def clean_rows(df_to_clean):
    return df_to_clean[df_to_clean['success'] == True]

comedy = clean_rows(comedy)
documentary = clean_rows(documentary)
horror = clean_rows(horror)

print(set(comedy.success))
print(set(documentary.success))
print(set(horror.success))
# Out:
# {True}
# {True}
# {True}

# %%
columns_to_drop = ['success', 'pupil_classification', 'pupil_center_x', 'pupil_center_y', 'iris_center_x', 'iris_center_y', 'gaze_magnitude', 'concentricity_score']

comedy.drop(columns=columns_to_drop, inplace=True)
documentary.drop(columns=columns_to_drop, inplace=True)
horror.drop(columns=columns_to_drop, inplace=True)

# %%
comedy
# Out:
#       pupil_diameter_mm  iris_diameter_mm  pupil_iris_ratio gaze_direction  \
# 0                   0.0              11.8               0.0         Center
# 1                   0.0              11.8               0.0         Center
# 2                   0.0              11.8               0.0         Center
# 3                   0.0              11.8               0.0         Center
# 4                   0.0              11.8               0.0         Center
# ...                 ...               ...               ...            ...
# 2564                0.0              11.8               0.0         Center
# 2565                0.0              11.8               0.0         Center
# 2566                0.0              11.8               0.0         Center
# 2567                0.0              11.8               0.0         Center
# 2568                0.0              11.8               0.0         Center
#
#       overall_confidence  pupil_detected  iris_detected  pupil_circularity  \
# 0               0.312995            True          False           0.417327
# 1               0.255435            True          False           0.340579
# 2               0.226924            True          False           0.302566
# 3               0.227541            True          False           0.303388
# 4               0.329428            True          False           0.439237
# ...                  ...             ...            ...                ...
# 2564            0.298038            True          False           0.397384
# 2565            0.358844            True          False           0.478458
# 2566            0.366174            True          False           0.488232
# 2567            0.336177            True          False           0.448236
# 2568            0.382816            True          False           0.510422
#
#       timestamp
# 0           0.0
# 1           0.5
# 2           1.0
# 3           1.5
# 4          10.0
# ...         ...
# 2564      997.5
# 2565      998.0
# 2566      998.5
# 2567      999.0
# 2568      999.5
#
# [2569 rows x 9 columns]

# %%
# Convert timestamp (float seconds) to actual datetime
comedy['time'] = comedy['timestamp'].apply(lambda x: config["comedy"]["start_time"] + timedelta(seconds=x))
documentary['time'] = documentary['timestamp'].apply(lambda x: config["documentary"]["start_time"] + timedelta(seconds=x))
horror['time'] = horror['timestamp'].apply(lambda x: config["horror"]["start_time"] + timedelta(seconds=x))

comedy
# Out:
#       pupil_diameter_mm  iris_diameter_mm  pupil_iris_ratio gaze_direction  \
# 0                   0.0              11.8               0.0         Center
# 1                   0.0              11.8               0.0         Center
# 2                   0.0              11.8               0.0         Center
# 3                   0.0              11.8               0.0         Center
# 4                   0.0              11.8               0.0         Center
# ...                 ...               ...               ...            ...
# 2564                0.0              11.8               0.0         Center
# 2565                0.0              11.8               0.0         Center
# 2566                0.0              11.8               0.0         Center
# 2567                0.0              11.8               0.0         Center
# 2568                0.0              11.8               0.0         Center
#
#       overall_confidence  pupil_detected  iris_detected  pupil_circularity  \
# 0               0.312995            True          False           0.417327
# 1               0.255435            True          False           0.340579
# 2               0.226924            True          False           0.302566
# 3               0.227541            True          False           0.303388
# 4               0.329428            True          False           0.439237
# ...                  ...             ...            ...                ...
# 2564            0.298038            True          False           0.397384
# 2565            0.358844            True          False           0.478458
# 2566            0.366174            True          False           0.488232
# 2567            0.336177            True          False           0.448236
# 2568            0.382816            True          False           0.510422
#
#       timestamp                    time
# 0           0.0 2025-06-12 09:46:46.000
# 1           0.5 2025-06-12 09:46:46.500
# 2           1.0 2025-06-12 09:46:47.000
# 3           1.5 2025-06-12 09:46:47.500
# 4          10.0 2025-06-12 09:46:56.000
# ...         ...                     ...
# 2564      997.5 2025-06-12 10:03:23.500
# 2565      998.0 2025-06-12 10:03:24.000
# 2566      998.5 2025-06-12 10:03:24.500
# 2567      999.0 2025-06-12 10:03:25.000
# 2568      999.5 2025-06-12 10:03:25.500
#
# [2569 rows x 10 columns]

# %%
def reset_timestamp_column(df_to_reset):
    df_to_reset = df_to_reset.sort_values(by='time').reset_index(drop=True)
    df_to_reset['timestamp'] = df_to_reset['time'] 
    df_to_reset.drop(columns=['time'], inplace=True)
    return df_to_reset

comedy = reset_timestamp_column(comedy)
documentary = reset_timestamp_column(documentary)
horror = reset_timestamp_column(horror)

# %%
# comedy = comedy.set_index('timestamp')
# documentary = documentary.set_index('timestamp')
# horror = horror.set_index('timestamp')

# %%
comedy
# Out:
#       pupil_diameter_mm  iris_diameter_mm  pupil_iris_ratio gaze_direction  \
# 0                   0.0              11.8               0.0         Center
# 1                   0.0              11.8               0.0         Center
# 2                   0.0              11.8               0.0         Center
# 3                   0.0              11.8               0.0         Center
# 4                   0.0              11.8               0.0         Center
# ...                 ...               ...               ...            ...
# 2564                0.0              11.8               0.0         Center
# 2565                0.0              11.8               0.0         Center
# 2566                0.0              11.8               0.0         Center
# 2567                0.0              11.8               0.0         Center
# 2568                0.0              11.8               0.0         Center
#
#       overall_confidence  pupil_detected  iris_detected  pupil_circularity  \
# 0               0.312995            True          False           0.417327
# 1               0.255435            True          False           0.340579
# 2               0.226924            True          False           0.302566
# 3               0.227541            True          False           0.303388
# 4               0.277632            True          False           0.370176
# ...                  ...             ...            ...                ...
# 2564            0.294516            True          False           0.392687
# 2565            0.347902            True          False           0.463870
# 2566            0.245957            True          False           0.327942
# 2567            0.295820            True          False           0.394427
# 2568            0.324850            True          False           0.433133
#
#                    timestamp
# 0    2025-06-12 09:46:46.000
# 1    2025-06-12 09:46:46.500
# 2    2025-06-12 09:46:47.000
# 3    2025-06-12 09:46:47.500
# 4    2025-06-12 09:46:48.000
# ...                      ...
# 2564 2025-06-12 10:08:08.000
# 2565 2025-06-12 10:08:08.500
# 2566 2025-06-12 10:08:09.000
# 2567 2025-06-12 10:08:09.500
# 2568 2025-06-12 10:08:10.000
#
# [2569 rows x 9 columns]

# %%
numeric_cols = ['pupil_diameter_mm', 'iris_diameter_mm', 'pupil_iris_ratio', 'overall_confidence','pupil_circularity', 'timestamp']
non_numeric_cols = ['gaze_direction', 'pupil_detected', 'iris_detected']

def aggregate_data(df_to_aggregate):
    df_to_aggregate['timestamp'] = pd.to_datetime(df_to_aggregate['timestamp']).dt.tz_localize(None)
    df_to_aggregate['time_rounded'] = df_to_aggregate['timestamp'].dt.floor('1s')
    

    # Function to apply to each group
    def agg_group(group):
        numeric_part = group[numeric_cols].mean()
        best_row = group.loc[group['overall_confidence'].idxmax(), non_numeric_cols]
        return pd.concat([numeric_part, best_row])

    aggregated = df_to_aggregate.groupby('time_rounded').apply(agg_group).reset_index()
    return aggregated

# %%
comedy_agg = aggregate_data(comedy)
documentary_agg = aggregate_data(documentary)
horror_agg = aggregate_data(horror)
# Out:
# C:\Users\aimen\AppData\Local\Temp\ipykernel_16608\2531117646.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   aggregated = df_to_aggregate.groupby('time_rounded').apply(agg_group).reset_index()
# C:\Users\aimen\AppData\Local\Temp\ipykernel_16608\2531117646.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   aggregated = df_to_aggregate.groupby('time_rounded').apply(agg_group).reset_index()
# C:\Users\aimen\AppData\Local\Temp\ipykernel_16608\2531117646.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   aggregated = df_to_aggregate.groupby('time_rounded').apply(agg_group).reset_index()

# %%
comedy_agg
# Out:
#             time_rounded  pupil_diameter_mm  iris_diameter_mm  \
# 0    2025-06-12 09:46:46                0.0              11.8
# 1    2025-06-12 09:46:47                0.0              11.8
# 2    2025-06-12 09:46:48                0.0              11.8
# 3    2025-06-12 09:46:49                0.0              11.8
# 4    2025-06-12 09:46:50                0.0              11.8
# ...                  ...                ...               ...
# 1280 2025-06-12 10:08:06                0.0              11.8
# 1281 2025-06-12 10:08:07                0.0              11.8
# 1282 2025-06-12 10:08:08                0.0              11.8
# 1283 2025-06-12 10:08:09                0.0              11.8
# 1284 2025-06-12 10:08:10                0.0              11.8
#
#       pupil_iris_ratio  overall_confidence  pupil_circularity  \
# 0                  0.0            0.284215           0.378953
# 1                  0.0            0.227233           0.302977
# 2                  0.0            0.337234           0.449646
# 3                  0.0            0.296756           0.395675
# 4                  0.0            0.291273           0.388364
# ...                ...                 ...                ...
# 1280               0.0            0.358124           0.477499
# 1281               0.0            0.268669           0.358225
# 1282               0.0            0.321209           0.428279
# 1283               0.0            0.270888           0.361184
# 1284               0.0            0.324850           0.433133
#
#                          timestamp gaze_direction  pupil_detected  \
# 0    2025-06-12 09:46:46.249999872         Center            True
# 1    2025-06-12 09:46:47.249999872         Center            True
# 2    2025-06-12 09:46:48.249999872         Center            True
# 3    2025-06-12 09:46:49.249999872         Center            True
# 4    2025-06-12 09:46:50.249999872         Center            True
# ...                            ...            ...             ...
# 1280 2025-06-12 10:08:06.249999872         Center            True
# 1281 2025-06-12 10:08:07.249999872         Center            True
# 1282 2025-06-12 10:08:08.249999872         Center            True
# 1283 2025-06-12 10:08:09.249999872         Center            True
# 1284 2025-06-12 10:08:10.000000000         Center            True
#
#       iris_detected
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ...             ...
# 1280          False
# 1281          False
# 1282          False
# 1283          False
# 1284          False
#
# [1285 rows x 10 columns]

# %%
comedy_agg.drop(columns=['timestamp'], inplace=True)
documentary_agg.drop(columns=['timestamp'], inplace=True)
horror_agg.drop(columns=['timestamp'], inplace=True)

comedy_agg['timestamp'] = comedy_agg['time_rounded']
documentary_agg['timestamp'] = documentary_agg['time_rounded']
horror_agg['timestamp'] = horror_agg['time_rounded']

comedy_agg.drop(columns=['time_rounded'], inplace=True)
documentary_agg.drop(columns=['time_rounded'], inplace=True)
horror_agg.drop(columns=['time_rounded'], inplace=True)

# %%
comedy_agg.set_index('timestamp', inplace=True)
documentary_agg.set_index('timestamp', inplace=True)
horror_agg.set_index('timestamp', inplace=True)

# %%
comedy_agg
# Out:
#                      pupil_diameter_mm  iris_diameter_mm  pupil_iris_ratio  \
