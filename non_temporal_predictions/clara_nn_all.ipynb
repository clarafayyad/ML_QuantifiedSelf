# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scienceplots
plt.style.use(['science','ieee'])

# Increase font sizes manually
plt.rcParams.update({
    'axes.titlesize': 16,
    'axes.labelsize': 14,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10,
    'legend.fontsize': 12,
    'figure.titlesize': 18
})

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import class_weight

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.utils import to_categorical

import re

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load data & Select features

# %%
df = pd.read_csv("feature_engineering/data_with_new_features_v3.csv")
participant_col_name = 'participant'

# %%
import re

def select_feature_groups(df, group_names):
    base = ['timestamp', 'participant', 'genre']

    groups = {
        "raw": [
            'heart_rate', 'x_coordinate', 'y_coordinate', 'pupil_diameter_mm',
            'iris_diameter_mm', 'pupil_iris_ratio'],
        'head_movement':['head_displacement', 'head_velocity', 'head_direction_change_rate', 'head_stability', 'centered_x', 'centered_y'],
        "time_domain": [col for col in df.columns if col.startswith("td_")],
        "fft": [col for col in df.columns if "_fft_" in col],
        "entropy": [col for col in df.columns if "_entropy" in col],
        "stat_moments": [col for col in df.columns if any(k in col for k in ['_skew', '_kurtosis'])],
        "bucket": [col for col in df.columns if col.endswith("_bucket")],
        "bucket_transitions": [col for col in df.columns if re.match(r'.*_(low|normal|high)_(low|normal|high)$', col)],
        "nonlinear": [col for col in df.columns if "_entropy" in col or "_sample_entropy" in col or "_approx_entropy" in col],
    }

    selected = set(base)
    for name in group_names:
        selected.update(groups.get(name, []))

    return df[list(selected)]


# df = select_feature_groups(df, ['raw', 'head_movement'])

# %% [markdown]
# ## Preprocess & Split

# %%
# Exclude non-numeric columns
exclude_cols = [participant_col_name, 'timestamp', 'genre']
numeric_cols = df.drop(columns=exclude_cols).select_dtypes(include=[np.number]).columns.tolist()

# Global normalization
scaler = StandardScaler()
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# Encode other categorical columns (if any, excluding participant/timestamp/genre)
categorical_cols = df.select_dtypes(include=['object']).columns.difference(exclude_cols)


for col in categorical_cols:
    df[col] = LabelEncoder().fit_transform(df[col])

# Encode the target variable 'genre'
genre_label_encoder = LabelEncoder()
df['genre_encoded'] = genre_label_encoder.fit_transform(df['genre'])

# Split Clara for test only
test_df = df[df[participant_col_name] == 'clara'].copy()

# Combine Kenji and Aimen data
train_val_df = df[df[participant_col_name].isin(['aimen', 'kenji'])].copy()

# Stratified split into train (80%) and val (20%) from Kenji + Aimen
train_df, val_df = train_test_split(
    train_val_df,
    test_size=0.2,
    stratify=train_val_df['genre_encoded'],
    random_state=42
)

# Final test set is Clara
final_test_df = test_df.copy()

# %%
print(set(train_df[participant_col_name].values))
print(set(val_df[participant_col_name].values))
print(set(final_test_df[participant_col_name].values))
# Out:
# {'aimen', 'kenji'}
# {'aimen', 'kenji'}
# {'clara'}

# %%
print(set(train_df['genre'].values))
print(set(val_df['genre'].values))
print(set(final_test_df['genre'].values))

print(train_df['genre_encoded'].value_counts())
print(val_df['genre_encoded'].value_counts())
print(final_test_df['genre_encoded'].value_counts())
# Out:
# {'documentary', 'comedy', 'horror'}
# {'documentary', 'comedy', 'horror'}
# {'documentary', 'comedy', 'horror'}
# genre_encoded
# 2    1705
# 0    1297
# 1    1183
# Name: count, dtype: int64
# genre_encoded
# 2    427
# 0    324
# 1    296
# Name: count, dtype: int64
# genre_encoded
# 1    1560
# 0    1340
# 2    1212
# Name: count, dtype: int64

# %%
# define features and labels
X_train = train_df[numeric_cols]
y_train = train_df['genre_encoded']

X_val = val_df[numeric_cols]
y_val = val_df['genre_encoded']

X_test = final_test_df[numeric_cols]
y_test = final_test_df['genre_encoded']

# %%
# One-hot encode the genre labels
y_train_cat = to_categorical(y_train, num_classes=3)
y_val_cat = to_categorical(y_val, num_classes=3)
y_test_cat = to_categorical(y_test, num_classes=3)

# %% [markdown]
# ## Select best features

# %%
from sklearn.feature_selection import SelectKBest, f_classif

# Select top 10 features using f_classif
k = 10
selector = SelectKBest(score_func=f_classif, k=k)

# Fit only on training data
X_train_selected = selector.fit_transform(X_train, y_train)

# Apply same transformation to val and test
X_val_selected = selector.transform(X_val)
X_test_selected = selector.transform(X_test)

# Get names of selected features (optional, for inspection)
selected_feature_names = X_train.columns[selector.get_support()].tolist()
print(f"Top {k} selected features:\n", selected_feature_names)
# Out:
# Top 10 selected features:
#  ['y_coordinate', 'centered_y', 'td_heart_rate_second_order_diff_mean', 'td_centered_y_mean', 'td_centered_y_std', 'td_centered_y_min', 'td_centered_y_range', 'td_centered_y_mean_abs_change', 'td_pupil_diameter_mm_mean', 'td_pupil_iris_ratio_mean']

# %% [markdown]
# ## Build & train model

# %%
class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train_cat.argmax(axis=1)),
    y=y_train_cat.argmax(axis=1)
)

class_weight_dict = dict(enumerate(class_weights))

# %%
def create_model(input_dim):
    model = Sequential([
        Dense(32, input_dim=input_dim),
        LeakyReLU(alpha=0.01),
        BatchNormalization(),
        Dropout(0.2),

        Dense(16),
        LeakyReLU(alpha=0.01),
        BatchNormalization(),
        Dropout(0.2),

        Dense(3, activation='softmax')
    ])
    
    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='categorical_crossentropy',
        metrics=['accuracy', 'Precision', 'Recall']
    )
    
    return model

# Model init
model = create_model(X_train_selected.shape[1])

# Callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
]


# Training
history = model.fit(
    X_train_selected, y_train_cat,
    validation_data=(X_val_selected, y_val_cat),
    epochs=30,
    batch_size=32,
    callbacks=callbacks,
    verbose=1,
     class_weight=class_weight_dict
)
# Out:
# Epoch 1/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Precision: 0.5331 - Recall: 0.4137 - accuracy: 0.5127 - loss: 1.1758 - val_Precision: 0.8982 - val_Recall: 0.7077 - val_accuracy: 0.8042 - val_loss: 0.5484 - learning_rate: 0.0010
# Epoch 2/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - Precision: 0.8328 - Recall: 0.7554 - accuracy: 0.8000 - loss: 0.5115 - val_Precision: 0.9032 - val_Recall: 0.8558 - val_accuracy: 0.8768 - val_loss: 0.3375 - learning_rate: 0.0010
# Epoch 3/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - Precision: 0.8601 - Recall: 0.8085 - accuracy: 0.8394 - loss: 0.4228 - val_Precision: 0.9228 - val_Recall: 0.8911 - val_accuracy: 0.9083 - val_loss: 0.2726 - learning_rate: 0.0010
# Epoch 4/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - Precision: 0.8766 - Recall: 0.8498 - accuracy: 0.8638 - loss: 0.3659 - val_Precision: 0.9275 - val_Recall: 0.9160 - val_accuracy: 0.9198 - val_loss: 0.2366 - learning_rate: 0.0010
# Epoch 5/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - Precision: 0.8907 - Recall: 0.8694 - accuracy: 0.8817 - loss: 0.3364 - val_Precision: 0.9381 - val_Recall: 0.9265 - val_accuracy: 0.9331 - val_loss: 0.2084 - learning_rate: 0.0010
# Epoch 6/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - Precision: 0.8912 - Recall: 0.8734 - accuracy: 0.8834 - loss: 0.3195 - val_Precision: 0.9237 - val_Recall: 0.9140 - val_accuracy: 0.9179 - val_loss: 0.2096 - learning_rate: 0.0010
# Epoch 7/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step - Precision: 0.8922 - Recall: 0.8809 - accuracy: 0.8874 - loss: 0.3049 - val_Precision: 0.9434 - val_Recall: 0.9389 - val_accuracy: 0.9398 - val_loss: 0.1698 - learning_rate: 0.0010
# Epoch 8/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step - Precision: 0.9059 - Recall: 0.8915 - accuracy: 0.8978 - loss: 0.2928 - val_Precision: 0.9510 - val_Recall: 0.9446 - val_accuracy: 0.9484 - val_loss: 0.1555 - learning_rate: 0.0010
# Epoch 9/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step - Precision: 0.9116 - Recall: 0.8959 - accuracy: 0.9050 - loss: 0.2657 - val_Precision: 0.9596 - val_Recall: 0.9522 - val_accuracy: 0.9570 - val_loss: 0.1494 - learning_rate: 0.0010
# Epoch 10/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step - Precision: 0.9201 - Recall: 0.9098 - accuracy: 0.9136 - loss: 0.2451 - val_Precision: 0.9625 - val_Recall: 0.9570 - val_accuracy: 0.9618 - val_loss: 0.1365 - learning_rate: 0.0010
# Epoch 11/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step - Precision: 0.9170 - Recall: 0.9098 - accuracy: 0.9131 - loss: 0.2435 - val_Precision: 0.9636 - val_Recall: 0.9599 - val_accuracy: 0.9628 - val_loss: 0.1215 - learning_rate: 0.0010
# Epoch 12/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - Precision: 0.9244 - Recall: 0.9158 - accuracy: 0.9186 - loss: 0.2286 - val_Precision: 0.9722 - val_Recall: 0.9694 - val_accuracy: 0.9713 - val_loss: 0.1139 - learning_rate: 0.0010
# Epoch 13/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - Precision: 0.9346 - Recall: 0.9258 - accuracy: 0.9305 - loss: 0.1962 - val_Precision: 0.9656 - val_Recall: 0.9637 - val_accuracy: 0.9647 - val_loss: 0.1059 - learning_rate: 0.0010
# Epoch 14/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - Precision: 0.9304 - Recall: 0.9255 - accuracy: 0.9288 - loss: 0.2098 - val_Precision: 0.9675 - val_Recall: 0.9656 - val_accuracy: 0.9656 - val_loss: 0.0961 - learning_rate: 0.0010
# Epoch 15/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - Precision: 0.9402 - Recall: 0.9330 - accuracy: 0.9354 - loss: 0.1864 - val_Precision: 0.9665 - val_Recall: 0.9647 - val_accuracy: 0.9647 - val_loss: 0.0920 - learning_rate: 0.0010
# Epoch 16/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - Precision: 0.9456 - Recall: 0.9387 - accuracy: 0.9416 - loss: 0.1738 - val_Precision: 0.9685 - val_Recall: 0.9675 - val_accuracy: 0.9675 - val_loss: 0.0894 - learning_rate: 0.0010
# Epoch 17/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step - Precision: 0.9452 - Recall: 0.9398 - accuracy: 0.9422 - loss: 0.1687 - val_Precision: 0.9751 - val_Recall: 0.9733 - val_accuracy: 0.9752 - val_loss: 0.0836 - learning_rate: 0.0010
# Epoch 18/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step - Precision: 0.9430 - Recall: 0.9372 - accuracy: 0.9398 - loss: 0.1801 - val_Precision: 0.9675 - val_Recall: 0.9666 - val_accuracy: 0.9675 - val_loss: 0.0912 - learning_rate: 0.0010
# Epoch 19/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step - Precision: 0.9323 - Recall: 0.9276 - accuracy: 0.9298 - loss: 0.1839 - val_Precision: 0.9646 - val_Recall: 0.9637 - val_accuracy: 0.9647 - val_loss: 0.0964 - learning_rate: 0.0010
# Epoch 20/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step - Precision: 0.9556 - Recall: 0.9517 - accuracy: 0.9539 - loss: 0.1510 - val_Precision: 0.9809 - val_Recall: 0.9790 - val_accuracy: 0.9799 - val_loss: 0.0793 - learning_rate: 0.0010
# Epoch 21/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step - Precision: 0.9529 - Recall: 0.9445 - accuracy: 0.9511 - loss: 0.1595 - val_Precision: 0.9761 - val_Recall: 0.9761 - val_accuracy: 0.9761 - val_loss: 0.0714 - learning_rate: 0.0010
# Epoch 22/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step - Precision: 0.9479 - Recall: 0.9389 - accuracy: 0.9431 - loss: 0.1669 - val_Precision: 0.9742 - val_Recall: 0.9742 - val_accuracy: 0.9742 - val_loss: 0.0721 - learning_rate: 0.0010
# Epoch 23/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step - Precision: 0.9523 - Recall: 0.9478 - accuracy: 0.9487 - loss: 0.1624 - val_Precision: 0.9761 - val_Recall: 0.9761 - val_accuracy: 0.9761 - val_loss: 0.0678 - learning_rate: 0.0010
# Epoch 24/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step - Precision: 0.9539 - Recall: 0.9488 - accuracy: 0.9512 - loss: 0.1553 - val_Precision: 0.9733 - val_Recall: 0.9733 - val_accuracy: 0.9733 - val_loss: 0.0715 - learning_rate: 0.0010
# Epoch 25/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - Precision: 0.9557 - Recall: 0.9526 - accuracy: 0.9532 - loss: 0.1494 - val_Precision: 0.9685 - val_Recall: 0.9685 - val_accuracy: 0.9685 - val_loss: 0.0744 - learning_rate: 0.0010
# Epoch 26/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step - Precision: 0.9474 - Recall: 0.9445 - accuracy: 0.9457 - loss: 0.1536 - val_Precision: 0.9771 - val_Recall: 0.9771 - val_accuracy: 0.9771 - val_loss: 0.0669 - learning_rate: 0.0010
# Epoch 27/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step - Precision: 0.9586 - Recall: 0.9559 - accuracy: 0.9571 - loss: 0.1318 - val_Precision: 0.9742 - val_Recall: 0.9742 - val_accuracy: 0.9742 - val_loss: 0.0678 - learning_rate: 0.0010
# Epoch 28/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step - Precision: 0.9539 - Recall: 0.9509 - accuracy: 0.9525 - loss: 0.1438 - val_Precision: 0.9809 - val_Recall: 0.9809 - val_accuracy: 0.9809 - val_loss: 0.0602 - learning_rate: 0.0010
# Epoch 29/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - Precision: 0.9550 - Recall: 0.9513 - accuracy: 0.9528 - loss: 0.1315 - val_Precision: 0.9799 - val_Recall: 0.9799 - val_accuracy: 0.9799 - val_loss: 0.0595 - learning_rate: 0.0010
# Epoch 30/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step - Precision: 0.9567 - Recall: 0.9528 - accuracy: 0.9551 - loss: 0.1410 - val_Precision: 0.9790 - val_Recall: 0.9780 - val_accuracy: 0.9790 - val_loss: 0.0600 - learning_rate: 0.0010

# %%
from sklearn.model_selection import StratifiedKFold

# Set up
n_splits = 5
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

fold = 1
histories = []
test_scores = []

for train_idx, val_idx in skf.split(X_train_selected, y_train_cat.argmax(axis=1)):
    print(f"\n--- Fold {fold} ---")
    
    # Split data
    X_train_fold, X_val_fold = X_train_selected[train_idx], X_train_selected[val_idx]
    y_train_fold, y_val_fold = y_train_cat[train_idx], y_train_cat[val_idx]
    
    # Compute class weights
    class_weights = class_weight.compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_train_fold.argmax(axis=1)),
        y=y_train_fold.argmax(axis=1)
    )
    class_weight_dict = dict(enumerate(class_weights))
    
    # Create and compile model
    model = create_model(X_train_selected.shape[1])
    
    # Train model
    history = model.fit(
        X_train_fold, y_train_fold,
        validation_data=(X_val_fold, y_val_fold),
        epochs=30,
        batch_size=32,
        callbacks=callbacks,
        verbose=1,
        class_weight=class_weight_dict
    )
    
    # Save history and optionally evaluate on test set
    histories.append(history)
    score = model.evaluate(X_test_selected, y_test_cat, verbose=0)
    test_scores.append(score)
    
    fold += 1

# Average test performance across folds
avg_test_scores = np.mean(test_scores, axis=0)
print("\nAverage test scores across folds:")
print(f"Loss: {avg_test_scores[0]:.4f} | Accuracy: {avg_test_scores[1]:.4f}")
# Out:
# --- Fold 1 ---
# Epoch 1/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Precision: 0.5959 - Recall: 0.4447 - accuracy: 0.5436 - loss: 1.0271 - val_Precision: 0.8782 - val_Recall: 0.6547 - val_accuracy: 0.7969 - val_loss: 0.5574 - learning_rate: 0.0010
# Epoch 2/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - Precision: 0.8326 - Recall: 0.7421 - accuracy: 0.7992 - loss: 0.5026 - val_Precision: 0.9241 - val_Recall: 0.8148 - val_accuracy: 0.8984 - val_loss: 0.3795 - learning_rate: 0.0010
# Epoch 3/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step - Precision: 0.8688 - Recall: 0.8072 - accuracy: 0.8449 - loss: 0.4314 - val_Precision: 0.9279 - val_Recall: 0.9068 - val_accuracy: 0.9188 - val_loss: 0.2987 - learning_rate: 0.0010
# Epoch 4/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - Precision: 0.8927 - Recall: 0.8503 - accuracy: 0.8701 - loss: 0.3535 - val_Precision: 0.9418 - val_Recall: 0.9283 - val_accuracy: 0.9355 - val_loss: 0.2381 - learning_rate: 0.0010
# Epoch 5/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step - Precision: 0.8841 - Recall: 0.8578 - accuracy: 0.8704 - loss: 0.3275 - val_Precision: 0.9457 - val_Recall: 0.9355 - val_accuracy: 0.9379 - val_loss: 0.2191 - learning_rate: 0.0010
# Epoch 6/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step - Precision: 0.9137 - Recall: 0.8924 - accuracy: 0.9069 - loss: 0.2724 - val_Precision: 0.9554 - val_Recall: 0.9474 - val_accuracy: 0.9534 - val_loss: 0.1744 - learning_rate: 0.0010
# Epoch 7/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - Precision: 0.9017 - Recall: 0.8832 - accuracy: 0.8926 - loss: 0.2776 - val_Precision: 0.9566 - val_Recall: 0.9486 - val_accuracy: 0.9546 - val_loss: 0.1460 - learning_rate: 0.0010
# Epoch 8/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - Precision: 0.9137 - Recall: 0.9013 - accuracy: 0.9101 - loss: 0.2693 - val_Precision: 0.9675 - val_Recall: 0.9618 - val_accuracy: 0.9642 - val_loss: 0.1296 - learning_rate: 0.0010
# Epoch 9/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - Precision: 0.9151 - Recall: 0.9027 - accuracy: 0.9100 - loss: 0.2522 - val_Precision: 0.9653 - val_Recall: 0.9630 - val_accuracy: 0.9630 - val_loss: 0.1165 - learning_rate: 0.0010
# Epoch 10/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - Precision: 0.9277 - Recall: 0.9171 - accuracy: 0.9229 - loss: 0.2406 - val_Precision: 0.9676 - val_Recall: 0.9642 - val_accuracy: 0.9665 - val_loss: 0.1039 - learning_rate: 0.0010
# Epoch 11/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - Precision: 0.9219 - Recall: 0.9107 - accuracy: 0.9180 - loss: 0.2421 - val_Precision: 0.9628 - val_Recall: 0.9582 - val_accuracy: 0.9618 - val_loss: 0.1156 - learning_rate: 0.0010
# Epoch 12/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - Precision: 0.9346 - Recall: 0.9256 - accuracy: 0.9303 - loss: 0.2039 - val_Precision: 0.9664 - val_Recall: 0.9630 - val_accuracy: 0.9654 - val_loss: 0.0982 - learning_rate: 0.0010
# Epoch 13/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - Precision: 0.9445 - Recall: 0.9373 - accuracy: 0.9417 - loss: 0.1709 - val_Precision: 0.9737 - val_Recall: 0.9725 - val_accuracy: 0.9737 - val_loss: 0.0905 - learning_rate: 0.0010
# Epoch 14/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - Precision: 0.9426 - Recall: 0.9351 - accuracy: 0.9404 - loss: 0.2030 - val_Precision: 0.9760 - val_Recall: 0.9713 - val_accuracy: 0.9761 - val_loss: 0.0919 - learning_rate: 0.0010
# Epoch 15/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - Precision: 0.9323 - Recall: 0.9220 - accuracy: 0.9275 - loss: 0.1937 - val_Precision: 0.9749 - val_Recall: 0.9725 - val_accuracy: 0.9737 - val_loss: 0.0860 - learning_rate: 0.0010
# Epoch 16/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step - Precision: 0.9506 - Recall: 0.9421 - accuracy: 0.9468 - loss: 0.1712 - val_Precision: 0.9737 - val_Recall: 0.9737 - val_accuracy: 0.9737 - val_loss: 0.0786 - learning_rate: 0.0010
# Epoch 17/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step - Precision: 0.9353 - Recall: 0.9271 - accuracy: 0.9317 - loss: 0.1861 - val_Precision: 0.9737 - val_Recall: 0.9725 - val_accuracy: 0.9737 - val_loss: 0.0818 - learning_rate: 0.0010
# Epoch 18/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - Precision: 0.9355 - Recall: 0.9270 - accuracy: 0.9312 - loss: 0.2020 - val_Precision: 0.9737 - val_Recall: 0.9713 - val_accuracy: 0.9725 - val_loss: 0.0799 - learning_rate: 0.0010
# Epoch 19/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - Precision: 0.9505 - Recall: 0.9447 - accuracy: 0.9483 - loss: 0.1653 - val_Precision: 0.9737 - val_Recall: 0.9713 - val_accuracy: 0.9725 - val_loss: 0.0787 - learning_rate: 0.0010
# Epoch 20/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - Precision: 0.9450 - Recall: 0.9389 - accuracy: 0.9427 - loss: 0.1761 - val_Precision: 0.9808 - val_Recall: 0.9773 - val_accuracy: 0.9797 - val_loss: 0.0727 - learning_rate: 0.0010
# Epoch 21/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - Precision: 0.9377 - Recall: 0.9313 - accuracy: 0.9355 - loss: 0.1915 - val_Precision: 0.9760 - val_Recall: 0.9737 - val_accuracy: 0.9749 - val_loss: 0.0774 - learning_rate: 0.0010
# Epoch 22/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - Precision: 0.9510 - Recall: 0.9477 - accuracy: 0.9499 - loss: 0.1579 - val_Precision: 0.9772 - val_Recall: 0.9749 - val_accuracy: 0.9773 - val_loss: 0.0737 - learning_rate: 0.0010
# Epoch 23/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - Precision: 0.9474 - Recall: 0.9432 - accuracy: 0.9456 - loss: 0.1577 - val_Precision: 0.9784 - val_Recall: 0.9761 - val_accuracy: 0.9785 - val_loss: 0.0706 - learning_rate: 0.0010
# Epoch 24/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - Precision: 0.9515 - Recall: 0.9435 - accuracy: 0.9481 - loss: 0.1591 - val_Precision: 0.9773 - val_Recall: 0.9773 - val_accuracy: 0.9773 - val_loss: 0.0666 - learning_rate: 0.0010
# Epoch 25/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - Precision: 0.9543 - Recall: 0.9504 - accuracy: 0.9513 - loss: 0.1516 - val_Precision: 0.9797 - val_Recall: 0.9785 - val_accuracy: 0.9797 - val_loss: 0.0732 - learning_rate: 0.0010
# Epoch 26/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - Precision: 0.9567 - Recall: 0.9528 - accuracy: 0.9551 - loss: 0.1471 - val_Precision: 0.9761 - val_Recall: 0.9749 - val_accuracy: 0.9761 - val_loss: 0.0766 - learning_rate: 0.0010
# Epoch 27/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - Precision: 0.9486 - Recall: 0.9451 - accuracy: 0.9459 - loss: 0.1626 - val_Precision: 0.9808 - val_Recall: 0.9785 - val_accuracy: 0.9797 - val_loss: 0.0648 - learning_rate: 0.0010
# Epoch 28/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - Precision: 0.9506 - Recall: 0.9462 - accuracy: 0.9487 - loss: 0.1615 - val_Precision: 0.9785 - val_Recall: 0.9773 - val_accuracy: 0.9785 - val_loss: 0.0624 - learning_rate: 0.0010
# Epoch 29/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - Precision: 0.9530 - Recall: 0.9496 - accuracy: 0.9517 - loss: 0.1451 - val_Precision: 0.9761 - val_Recall: 0.9761 - val_accuracy: 0.9761 - val_loss: 0.0640 - learning_rate: 0.0010
# Epoch 30/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - Precision: 0.9603 - Recall: 0.9563 - accuracy: 0.9572 - loss: 0.1321 - val_Precision: 0.9820 - val_Recall: 0.9797 - val_accuracy: 0.9821 - val_loss: 0.0649 - learning_rate: 0.0010
#
# --- Fold 2 ---
# Epoch 1/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Precision: 0.5103 - Recall: 0.4098 - accuracy: 0.4854 - loss: 1.2040 - val_Precision: 0.9386 - val_Recall: 0.7300 - val_accuracy: 0.8411 - val_loss: 0.5880 - learning_rate: 0.0010
# Epoch 2/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step - Precision: 0.8482 - Recall: 0.7710 - accuracy: 0.8116 - loss: 0.4886 - val_Precision: 0.9172 - val_Recall: 0.8602 - val_accuracy: 0.9044 - val_loss: 0.3777 - learning_rate: 0.0010
# Epoch 3/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - Precision: 0.8784 - Recall: 0.8297 - accuracy: 0.8544 - loss: 0.3940 - val_Precision: 0.9315 - val_Recall: 0.9104 - val_accuracy: 0.9211 - val_loss: 0.2796 - learning_rate: 0.0010
# Epoch 4/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step - Precision: 0.8883 - Recall: 0.8500 - accuracy: 0.8709 - loss: 0.3635 - val_Precision: 0.9320 - val_Recall: 0.9164 - val_accuracy: 0.9235 - val_loss: 0.2335 - learning_rate: 0.0010
# Epoch 5/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step - Precision: 0.8898 - Recall: 0.8609 - accuracy: 0.8742 - loss: 0.3362 - val_Precision: 0.9442 - val_Recall: 0.9295 - val_accuracy: 0.9343 - val_loss: 0.2057 - learning_rate: 0.0010
# Epoch 6/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - Precision: 0.9025 - Recall: 0.8782 - accuracy: 0.8929 - loss: 0.3060 - val_Precision: 0.9484 - val_Recall: 0.9438 - val_accuracy: 0.9450 - val_loss: 0.1897 - learning_rate: 0.0010
# Epoch 7/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step - Precision: 0.8997 - Recall: 0.8808 - accuracy: 0.8913 - loss: 0.2991 - val_Precision: 0.9435 - val_Recall: 0.9379 - val_accuracy: 0.9427 - val_loss: 0.1785 - learning_rate: 0.0010
# Epoch 8/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step - Precision: 0.8997 - Recall: 0.8847 - accuracy: 0.8954 - loss: 0.2818 - val_Precision: 0.9507 - val_Recall: 0.9450 - val_accuracy: 0.9486 - val_loss: 0.1651 - learning_rate: 0.0010
# Epoch 9/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - Precision: 0.9055 - Recall: 0.8895 - accuracy: 0.8989 - loss: 0.2828 - val_Precision: 0.9532 - val_Recall: 0.9486 - val_accuracy: 0.9498 - val_loss: 0.1541 - learning_rate: 0.0010
# Epoch 10/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - Precision: 0.9083 - Recall: 0.8893 - accuracy: 0.8992 - loss: 0.2566 - val_Precision: 0.9592 - val_Recall: 0.9558 - val_accuracy: 0.9582 - val_loss: 0.1488 - learning_rate: 0.0010
# Epoch 11/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - Precision: 0.9116 - Recall: 0.9021 - accuracy: 0.9056 - loss: 0.2611 - val_Precision: 0.9640 - val_Recall: 0.9594 - val_accuracy: 0.9618 - val_loss: 0.1413 - learning_rate: 0.0010
# Epoch 12/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - Precision: 0.9187 - Recall: 0.9058 - accuracy: 0.9137 - loss: 0.2350 - val_Precision: 0.9628 - val_Recall: 0.9594 - val_accuracy: 0.9630 - val_loss: 0.1400 - learning_rate: 0.0010
# Epoch 13/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - Precision: 0.9019 - Recall: 0.8949 - accuracy: 0.8997 - loss: 0.2536 - val_Precision: 0.9628 - val_Recall: 0.9582 - val_accuracy: 0.9606 - val_loss: 0.1323 - learning_rate: 0.0010
# Epoch 14/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step - Precision: 0.9235 - Recall: 0.9150 - accuracy: 0.9206 - loss: 0.2224 - val_Precision: 0.9605 - val_Recall: 0.9582 - val_accuracy: 0.9594 - val_loss: 0.1244 - learning_rate: 0.0010
# Epoch 15/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - Precision: 0.9330 - Recall: 0.9276 - accuracy: 0.9315 - loss: 0.2120 - val_Precision: 0.9665 - val_Recall: 0.9642 - val_accuracy: 0.9665 - val_loss: 0.1228 - learning_rate: 0.0010
# Epoch 16/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step - Precision: 0.9253 - Recall: 0.9181 - accuracy: 0.9205 - loss: 0.2214 - val_Precision: 0.9701 - val_Recall: 0.9677 - val_accuracy: 0.9677 - val_loss: 0.1163 - learning_rate: 0.0010
# Epoch 17/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - Precision: 0.9229 - Recall: 0.9167 - accuracy: 0.9182 - loss: 0.2386 - val_Precision: 0.9593 - val_Recall: 0.9570 - val_accuracy: 0.9582 - val_loss: 0.1135 - learning_rate: 0.0010
# Epoch 18/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - Precision: 0.9314 - Recall: 0.9232 - accuracy: 0.9283 - loss: 0.1889 - val_Precision: 0.9689 - val_Recall: 0.9677 - val_accuracy: 0.9689 - val_loss: 0.1106 - learning_rate: 0.0010
# Epoch 19/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step - Precision: 0.9316 - Recall: 0.9278 - accuracy: 0.9309 - loss: 0.1981 - val_Precision: 0.9713 - val_Recall: 0.9689 - val_accuracy: 0.9701 - val_loss: 0.1050 - learning_rate: 0.0010
# Epoch 20/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - Precision: 0.9262 - Recall: 0.9205 - accuracy: 0.9214 - loss: 0.2046 - val_Precision: 0.9689 - val_Recall: 0.9665 - val_accuracy: 0.9665 - val_loss: 0.1012 - learning_rate: 0.0010
# Epoch 21/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step - Precision: 0.9313 - Recall: 0.9274 - accuracy: 0.9290 - loss: 0.1867 - val_Precision: 0.9665 - val_Recall: 0.9654 - val_accuracy: 0.9654 - val_loss: 0.0976 - learning_rate: 0.0010
# Epoch 22/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - Precision: 0.9243 - Recall: 0.9198 - accuracy: 0.9227 - loss: 0.2105 - val_Precision: 0.9689 - val_Recall: 0.9677 - val_accuracy: 0.9677 - val_loss: 0.0948 - learning_rate: 0.0010
# Epoch 23/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - Precision: 0.9394 - Recall: 0.9347 - accuracy: 0.9379 - loss: 0.1715 - val_Precision: 0.9737 - val_Recall: 0.9713 - val_accuracy: 0.9725 - val_loss: 0.0967 - learning_rate: 0.0010
# Epoch 24/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - Precision: 0.9308 - Recall: 0.9234 - accuracy: 0.9267 - loss: 0.1942 - val_Precision: 0.9713 - val_Recall: 0.9701 - val_accuracy: 0.9713 - val_loss: 0.0888 - learning_rate: 0.0010
# Epoch 25/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step - Precision: 0.9342 - Recall: 0.9291 - accuracy: 0.9319 - loss: 0.1883 - val_Precision: 0.9701 - val_Recall: 0.9677 - val_accuracy: 0.9689 - val_loss: 0.0871 - learning_rate: 0.0010
# Epoch 26/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step - Precision: 0.9288 - Recall: 0.9265 - accuracy: 0.9276 - loss: 0.1931 - val_Precision: 0.9580 - val_Recall: 0.9546 - val_accuracy: 0.9570 - val_loss: 0.1088 - learning_rate: 0.0010
# Epoch 27/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - Precision: 0.9435 - Recall: 0.9355 - accuracy: 0.9407 - loss: 0.1670 - val_Precision: 0.9749 - val_Recall: 0.9725 - val_accuracy: 0.9737 - val_loss: 0.0806 - learning_rate: 0.0010
# Epoch 28/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step - Precision: 0.9444 - Recall: 0.9432 - accuracy: 0.9440 - loss: 0.1599 - val_Precision: 0.9761 - val_Recall: 0.9749 - val_accuracy: 0.9761 - val_loss: 0.0826 - learning_rate: 0.0010
# Epoch 29/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step - Precision: 0.9530 - Recall: 0.9507 - accuracy: 0.9513 - loss: 0.1480 - val_Precision: 0.9725 - val_Recall: 0.9701 - val_accuracy: 0.9713 - val_loss: 0.0865 - learning_rate: 0.0010
# Epoch 30/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step - Precision: 0.9512 - Recall: 0.9468 - accuracy: 0.9506 - loss: 0.1399 - val_Precision: 0.9796 - val_Recall: 0.9773 - val_accuracy: 0.9785 - val_loss: 0.0828 - learning_rate: 0.0010
#
# --- Fold 3 ---
# Epoch 1/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Precision: 0.6103 - Recall: 0.5127 - accuracy: 0.5701 - loss: 0.9512 - val_Precision: 0.9275 - val_Recall: 0.7646 - val_accuracy: 0.8865 - val_loss: 0.4958 - learning_rate: 0.0010
# Epoch 2/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - Precision: 0.8493 - Recall: 0.7857 - accuracy: 0.8236 - loss: 0.4630 - val_Precision: 0.9321 - val_Recall: 0.9020 - val_accuracy: 0.9188 - val_loss: 0.3222 - learning_rate: 0.0010
# Epoch 3/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - Precision: 0.8821 - Recall: 0.8463 - accuracy: 0.8672 - loss: 0.3702 - val_Precision: 0.9406 - val_Recall: 0.9271 - val_accuracy: 0.9355 - val_loss: 0.2473 - learning_rate: 0.0010
# Epoch 4/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - Precision: 0.8956 - Recall: 0.8716 - accuracy: 0.8842 - loss: 0.3104 - val_Precision: 0.9445 - val_Recall: 0.9355 - val_accuracy: 0.9391 - val_loss: 0.2158 - learning_rate: 0.0010
# Epoch 5/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - Precision: 0.9049 - Recall: 0.8853 - accuracy: 0.8983 - loss: 0.2946 - val_Precision: 0.9495 - val_Recall: 0.9438 - val_accuracy: 0.9462 - val_loss: 0.1895 - learning_rate: 0.0010
# Epoch 6/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - Precision: 0.9042 - Recall: 0.8875 - accuracy: 0.8970 - loss: 0.2884 - val_Precision: 0.9556 - val_Recall: 0.9510 - val_accuracy: 0.9534 - val_loss: 0.1835 - learning_rate: 0.0010
# Epoch 7/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - Precision: 0.9195 - Recall: 0.9092 - accuracy: 0.9142 - loss: 0.2377 - val_Precision: 0.9532 - val_Recall: 0.9486 - val_accuracy: 0.9498 - val_loss: 0.1645 - learning_rate: 0.0010
# Epoch 8/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - Precision: 0.9140 - Recall: 0.9038 - accuracy: 0.9089 - loss: 0.2605 - val_Precision: 0.9557 - val_Recall: 0.9534 - val_accuracy: 0.9546 - val_loss: 0.1604 - learning_rate: 0.0010
# Epoch 9/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step - Precision: 0.9190 - Recall: 0.9066 - accuracy: 0.9154 - loss: 0.2351 - val_Precision: 0.9533 - val_Recall: 0.9522 - val_accuracy: 0.9522 - val_loss: 0.1572 - learning_rate: 0.0010
# Epoch 10/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - Precision: 0.9146 - Recall: 0.9067 - accuracy: 0.9116 - loss: 0.2277 - val_Precision: 0.9557 - val_Recall: 0.9534 - val_accuracy: 0.9546 - val_loss: 0.1488 - learning_rate: 0.0010
# Epoch 11/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step - Precision: 0.9141 - Recall: 0.9033 - accuracy: 0.9075 - loss: 0.2438 - val_Precision: 0.9496 - val_Recall: 0.9450 - val_accuracy: 0.9462 - val_loss: 0.1437 - learning_rate: 0.0010
# Epoch 12/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - Precision: 0.9352 - Recall: 0.9253 - accuracy: 0.9311 - loss: 0.1993 - val_Precision: 0.9508 - val_Recall: 0.9474 - val_accuracy: 0.9498 - val_loss: 0.1426 - learning_rate: 0.0010
# Epoch 13/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - Precision: 0.9311 - Recall: 0.9234 - accuracy: 0.9280 - loss: 0.2137 - val_Precision: 0.9545 - val_Recall: 0.9522 - val_accuracy: 0.9546 - val_loss: 0.1378 - learning_rate: 0.0010
# Epoch 14/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - Precision: 0.9296 - Recall: 0.9226 - accuracy: 0.9253 - loss: 0.2099 - val_Precision: 0.9545 - val_Recall: 0.9522 - val_accuracy: 0.9534 - val_loss: 0.1323 - learning_rate: 0.0010
# Epoch 15/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step - Precision: 0.9388 - Recall: 0.9318 - accuracy: 0.9356 - loss: 0.1898 - val_Precision: 0.9617 - val_Recall: 0.9594 - val_accuracy: 0.9606 - val_loss: 0.1276 - learning_rate: 0.0010
# Epoch 16/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step - Precision: 0.9498 - Recall: 0.9442 - accuracy: 0.9467 - loss: 0.1712 - val_Precision: 0.9401 - val_Recall: 0.9379 - val_accuracy: 0.9403 - val_loss: 0.1512 - learning_rate: 0.0010
# Epoch 17/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step - Precision: 0.9380 - Recall: 0.9336 - accuracy: 0.9356 - loss: 0.1853 - val_Precision: 0.9568 - val_Recall: 0.9534 - val_accuracy: 0.9558 - val_loss: 0.1326 - learning_rate: 0.0010
# Epoch 18/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step - Precision: 0.9470 - Recall: 0.9420 - accuracy: 0.9459 - loss: 0.1615 - val_Precision: 0.9605 - val_Recall: 0.9582 - val_accuracy: 0.9594 - val_loss: 0.1295 - learning_rate: 0.0010
# Epoch 19/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - Precision: 0.9455 - Recall: 0.9384 - accuracy: 0.9402 - loss: 0.1609 - val_Precision: 0.9605 - val_Recall: 0.9582 - val_accuracy: 0.9606 - val_loss: 0.1221 - learning_rate: 0.0010
# Epoch 20/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - Precision: 0.9509 - Recall: 0.9446 - accuracy: 0.9456 - loss: 0.1513 - val_Precision: 0.9581 - val_Recall: 0.9570 - val_accuracy: 0.9582 - val_loss: 0.1195 - learning_rate: 0.0010
# Epoch 21/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - Precision: 0.9379 - Recall: 0.9333 - accuracy: 0.9371 - loss: 0.1859 - val_Precision: 0.9617 - val_Recall: 0.9606 - val_accuracy: 0.9618 - val_loss: 0.1186 - learning_rate: 0.0010
# Epoch 22/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - Precision: 0.9464 - Recall: 0.9410 - accuracy: 0.9443 - loss: 0.1635 - val_Precision: 0.9581 - val_Recall: 0.9570 - val_accuracy: 0.9582 - val_loss: 0.1151 - learning_rate: 0.0010
# Epoch 23/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - Precision: 0.9543 - Recall: 0.9502 - accuracy: 0.9520 - loss: 0.1611 - val_Precision: 0.9629 - val_Recall: 0.9618 - val_accuracy: 0.9630 - val_loss: 0.1169 - learning_rate: 0.0010
# Epoch 24/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - Precision: 0.9473 - Recall: 0.9430 - accuracy: 0.9456 - loss: 0.1607 - val_Precision: 0.9593 - val_Recall: 0.9582 - val_accuracy: 0.9594 - val_loss: 0.1140 - learning_rate: 0.0010
# Epoch 25/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - Precision: 0.9475 - Recall: 0.9456 - accuracy: 0.9462 - loss: 0.1406 - val_Precision: 0.9593 - val_Recall: 0.9570 - val_accuracy: 0.9582 - val_loss: 0.1107 - learning_rate: 0.0010
# Epoch 26/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - Precision: 0.9439 - Recall: 0.9385 - accuracy: 0.9418 - loss: 0.1697 - val_Precision: 0.9569 - val_Recall: 0.9546 - val_accuracy: 0.9570 - val_loss: 0.1172 - learning_rate: 0.0010
# Epoch 27/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step - Precision: 0.9618 - Recall: 0.9566 - accuracy: 0.9597 - loss: 0.1233 - val_Precision: 0.9618 - val_Recall: 0.9618 - val_accuracy: 0.9618 - val_loss: 0.1067 - learning_rate: 0.0010
# Epoch 28/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step - Precision: 0.9388 - Recall: 0.9333 - accuracy: 0.9364 - loss: 0.1982 - val_Precision: 0.9641 - val_Recall: 0.9630 - val_accuracy: 0.9642 - val_loss: 0.1120 - learning_rate: 0.0010
# Epoch 29/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - Precision: 0.9554 - Recall: 0.9527 - accuracy: 0.9528 - loss: 0.1307 - val_Precision: 0.9594 - val_Recall: 0.9594 - val_accuracy: 0.9594 - val_loss: 0.1120 - learning_rate: 0.0010
# Epoch 30/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - Precision: 0.9545 - Recall: 0.9511 - accuracy: 0.9534 - loss: 0.1428 - val_Precision: 0.9618 - val_Recall: 0.9618 - val_accuracy: 0.9618 - val_loss: 0.1150 - learning_rate: 0.0010
#
# --- Fold 4 ---
# Epoch 1/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Precision: 0.5860 - Recall: 0.4380 - accuracy: 0.5387 - loss: 0.9796 - val_Precision: 0.9366 - val_Recall: 0.6882 - val_accuracy: 0.8781 - val_loss: 0.5677 - learning_rate: 0.0010
# Epoch 2/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - Precision: 0.8186 - Recall: 0.7289 - accuracy: 0.7855 - loss: 0.5220 - val_Precision: 0.9229 - val_Recall: 0.8292 - val_accuracy: 0.8638 - val_loss: 0.3680 - learning_rate: 0.0010
# Epoch 3/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step - Precision: 0.8641 - Recall: 0.8097 - accuracy: 0.8468 - loss: 0.4183 - val_Precision: 0.9142 - val_Recall: 0.8913 - val_accuracy: 0.9020 - val_loss: 0.2763 - learning_rate: 0.0010
# Epoch 4/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - Precision: 0.8910 - Recall: 0.8550 - accuracy: 0.8794 - loss: 0.3308 - val_Precision: 0.9270 - val_Recall: 0.9104 - val_accuracy: 0.9223 - val_loss: 0.2286 - learning_rate: 0.0010
# Epoch 5/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step - Precision: 0.8926 - Recall: 0.8639 - accuracy: 0.8803 - loss: 0.3178 - val_Precision: 0.9373 - val_Recall: 0.9283 - val_accuracy: 0.9331 - val_loss: 0.1845 - learning_rate: 0.0010
# Epoch 6/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - Precision: 0.8990 - Recall: 0.8754 - accuracy: 0.8895 - loss: 0.3219 - val_Precision: 0.9494 - val_Recall: 0.9415 - val_accuracy: 0.9462 - val_loss: 0.1587 - learning_rate: 0.0010
# Epoch 7/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step - Precision: 0.9112 - Recall: 0.8935 - accuracy: 0.9007 - loss: 0.2704 - val_Precision: 0.9554 - val_Recall: 0.9474 - val_accuracy: 0.9510 - val_loss: 0.1470 - learning_rate: 0.0010
# Epoch 8/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - Precision: 0.9014 - Recall: 0.8811 - accuracy: 0.8971 - loss: 0.2933 - val_Precision: 0.9543 - val_Recall: 0.9474 - val_accuracy: 0.9522 - val_loss: 0.1348 - learning_rate: 0.0010
# Epoch 9/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step - Precision: 0.8897 - Recall: 0.8785 - accuracy: 0.8854 - loss: 0.3077 - val_Precision: 0.9544 - val_Recall: 0.9498 - val_accuracy: 0.9510 - val_loss: 0.1398 - learning_rate: 0.0010
# Epoch 10/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step - Precision: 0.9062 - Recall: 0.8947 - accuracy: 0.8997 - loss: 0.2653 - val_Precision: 0.9532 - val_Recall: 0.9498 - val_accuracy: 0.9498 - val_loss: 0.1313 - learning_rate: 0.0010
# Epoch 11/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - Precision: 0.9224 - Recall: 0.9097 - accuracy: 0.9161 - loss: 0.2263 - val_Precision: 0.9568 - val_Recall: 0.9534 - val_accuracy: 0.9546 - val_loss: 0.1143 - learning_rate: 0.0010
# Epoch 12/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step - Precision: 0.9171 - Recall: 0.9055 - accuracy: 0.9110 - loss: 0.2451 - val_Precision: 0.9627 - val_Recall: 0.9570 - val_accuracy: 0.9582 - val_loss: 0.1080 - learning_rate: 0.0010
# Epoch 13/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - Precision: 0.9139 - Recall: 0.9070 - accuracy: 0.9112 - loss: 0.2345 - val_Precision: 0.9665 - val_Recall: 0.9654 - val_accuracy: 0.9654 - val_loss: 0.0996 - learning_rate: 0.0010
# Epoch 14/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step - Precision: 0.9229 - Recall: 0.9138 - accuracy: 0.9188 - loss: 0.2168 - val_Precision: 0.9593 - val_Recall: 0.9570 - val_accuracy: 0.9570 - val_loss: 0.1110 - learning_rate: 0.0010
# Epoch 15/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step - Precision: 0.9285 - Recall: 0.9205 - accuracy: 0.9243 - loss: 0.2098 - val_Precision: 0.9688 - val_Recall: 0.9654 - val_accuracy: 0.9654 - val_loss: 0.0985 - learning_rate: 0.0010
# Epoch 16/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - Precision: 0.9382 - Recall: 0.9347 - accuracy: 0.9368 - loss: 0.1835 - val_Precision: 0.9641 - val_Recall: 0.9618 - val_accuracy: 0.9618 - val_loss: 0.0963 - learning_rate: 0.0010
# Epoch 17/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - Precision: 0.9235 - Recall: 0.9196 - accuracy: 0.9218 - loss: 0.2305 - val_Precision: 0.9701 - val_Recall: 0.9677 - val_accuracy: 0.9689 - val_loss: 0.0874 - learning_rate: 0.0010
# Epoch 18/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step - Precision: 0.9266 - Recall: 0.9195 - accuracy: 0.9232 - loss: 0.2298 - val_Precision: 0.9700 - val_Recall: 0.9665 - val_accuracy: 0.9677 - val_loss: 0.0870 - learning_rate: 0.0010
# Epoch 19/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step - Precision: 0.9299 - Recall: 0.9274 - accuracy: 0.9286 - loss: 0.1827 - val_Precision: 0.9725 - val_Recall: 0.9713 - val_accuracy: 0.9713 - val_loss: 0.0803 - learning_rate: 0.0010
# Epoch 20/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - Precision: 0.9376 - Recall: 0.9325 - accuracy: 0.9352 - loss: 0.1966 - val_Precision: 0.9713 - val_Recall: 0.9701 - val_accuracy: 0.9701 - val_loss: 0.0767 - learning_rate: 0.0010
# Epoch 21/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step - Precision: 0.9405 - Recall: 0.9361 - accuracy: 0.9377 - loss: 0.1695 - val_Precision: 0.9725 - val_Recall: 0.9725 - val_accuracy: 0.9725 - val_loss: 0.0746 - learning_rate: 0.0010
# Epoch 22/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - Precision: 0.9460 - Recall: 0.9417 - accuracy: 0.9433 - loss: 0.1859 - val_Precision: 0.9737 - val_Recall: 0.9737 - val_accuracy: 0.9737 - val_loss: 0.0716 - learning_rate: 0.0010
# Epoch 23/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step - Precision: 0.9488 - Recall: 0.9405 - accuracy: 0.9455 - loss: 0.1764 - val_Precision: 0.9713 - val_Recall: 0.9701 - val_accuracy: 0.9701 - val_loss: 0.0738 - learning_rate: 0.0010
# Epoch 24/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step - Precision: 0.9415 - Recall: 0.9374 - accuracy: 0.9387 - loss: 0.1838 - val_Precision: 0.9772 - val_Recall: 0.9725 - val_accuracy: 0.9725 - val_loss: 0.0735 - learning_rate: 0.0010
# Epoch 25/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - Precision: 0.9462 - Recall: 0.9427 - accuracy: 0.9445 - loss: 0.1737 - val_Precision: 0.9701 - val_Recall: 0.9689 - val_accuracy: 0.9689 - val_loss: 0.0826 - learning_rate: 0.0010
# Epoch 26/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step - Precision: 0.9385 - Recall: 0.9347 - accuracy: 0.9371 - loss: 0.1719 - val_Precision: 0.9761 - val_Recall: 0.9749 - val_accuracy: 0.9761 - val_loss: 0.0693 - learning_rate: 0.0010
# Epoch 27/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - Precision: 0.9490 - Recall: 0.9461 - accuracy: 0.9475 - loss: 0.1703 - val_Precision: 0.9724 - val_Recall: 0.9689 - val_accuracy: 0.9689 - val_loss: 0.0734 - learning_rate: 0.0010
# Epoch 28/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step - Precision: 0.9578 - Recall: 0.9556 - accuracy: 0.9556 - loss: 0.1377 - val_Precision: 0.9749 - val_Recall: 0.9749 - val_accuracy: 0.9749 - val_loss: 0.0684 - learning_rate: 0.0010
# Epoch 29/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - Precision: 0.9535 - Recall: 0.9514 - accuracy: 0.9527 - loss: 0.1577 - val_Precision: 0.9761 - val_Recall: 0.9749 - val_accuracy: 0.9749 - val_loss: 0.0667 - learning_rate: 0.0010
# Epoch 30/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - Precision: 0.9594 - Recall: 0.9546 - accuracy: 0.9558 - loss: 0.1320 - val_Precision: 0.9737 - val_Recall: 0.9725 - val_accuracy: 0.9725 - val_loss: 0.0649 - learning_rate: 0.0010
#
# --- Fold 5 ---
# Epoch 1/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Precision: 0.5035 - Recall: 0.3750 - accuracy: 0.4867 - loss: 1.1298 - val_Precision: 0.9710 - val_Recall: 0.6404 - val_accuracy: 0.8387 - val_loss: 0.6089 - learning_rate: 0.0010
# Epoch 2/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step - Precision: 0.8375 - Recall: 0.7287 - accuracy: 0.7974 - loss: 0.5260 - val_Precision: 0.9530 - val_Recall: 0.8244 - val_accuracy: 0.8973 - val_loss: 0.3945 - learning_rate: 0.0010
# Epoch 3/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step - Precision: 0.8606 - Recall: 0.8052 - accuracy: 0.8408 - loss: 0.4106 - val_Precision: 0.9540 - val_Recall: 0.9176 - val_accuracy: 0.9379 - val_loss: 0.2601 - learning_rate: 0.0010
# Epoch 4/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step - Precision: 0.8891 - Recall: 0.8527 - accuracy: 0.8691 - loss: 0.3530 - val_Precision: 0.9600 - val_Recall: 0.9462 - val_accuracy: 0.9522 - val_loss: 0.2124 - learning_rate: 0.0010
# Epoch 5/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step - Precision: 0.8799 - Recall: 0.8553 - accuracy: 0.8696 - loss: 0.3261 - val_Precision: 0.9686 - val_Recall: 0.9594 - val_accuracy: 0.9630 - val_loss: 0.1723 - learning_rate: 0.0010
# Epoch 6/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - Precision: 0.9056 - Recall: 0.8885 - accuracy: 0.8961 - loss: 0.2982 - val_Precision: 0.9735 - val_Recall: 0.9654 - val_accuracy: 0.9665 - val_loss: 0.1552 - learning_rate: 0.0010
# Epoch 7/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step - Precision: 0.9076 - Recall: 0.8862 - accuracy: 0.8974 - loss: 0.2778 - val_Precision: 0.9759 - val_Recall: 0.9689 - val_accuracy: 0.9701 - val_loss: 0.1441 - learning_rate: 0.0010
# Epoch 8/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step - Precision: 0.9110 - Recall: 0.8938 - accuracy: 0.9006 - loss: 0.2722 - val_Precision: 0.9735 - val_Recall: 0.9665 - val_accuracy: 0.9689 - val_loss: 0.1273 - learning_rate: 0.0010
# Epoch 9/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - Precision: 0.9077 - Recall: 0.8945 - accuracy: 0.9023 - loss: 0.2582 - val_Precision: 0.9748 - val_Recall: 0.9689 - val_accuracy: 0.9713 - val_loss: 0.1202 - learning_rate: 0.0010
# Epoch 10/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - Precision: 0.9218 - Recall: 0.9079 - accuracy: 0.9172 - loss: 0.2265 - val_Precision: 0.9772 - val_Recall: 0.9713 - val_accuracy: 0.9737 - val_loss: 0.1074 - learning_rate: 0.0010
# Epoch 11/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - Precision: 0.9178 - Recall: 0.9052 - accuracy: 0.9145 - loss: 0.2347 - val_Precision: 0.9772 - val_Recall: 0.9737 - val_accuracy: 0.9761 - val_loss: 0.1007 - learning_rate: 0.0010
# Epoch 12/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step - Precision: 0.9282 - Recall: 0.9163 - accuracy: 0.9228 - loss: 0.2236 - val_Precision: 0.9760 - val_Recall: 0.9725 - val_accuracy: 0.9749 - val_loss: 0.0941 - learning_rate: 0.0010
# Epoch 13/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - Precision: 0.9312 - Recall: 0.9207 - accuracy: 0.9254 - loss: 0.2118 - val_Precision: 0.9796 - val_Recall: 0.9761 - val_accuracy: 0.9785 - val_loss: 0.0904 - learning_rate: 0.0010
# Epoch 14/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step - Precision: 0.9291 - Recall: 0.9218 - accuracy: 0.9246 - loss: 0.2075 - val_Precision: 0.9796 - val_Recall: 0.9761 - val_accuracy: 0.9785 - val_loss: 0.0853 - learning_rate: 0.0010
# Epoch 15/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - Precision: 0.9330 - Recall: 0.9202 - accuracy: 0.9260 - loss: 0.2123 - val_Precision: 0.9784 - val_Recall: 0.9761 - val_accuracy: 0.9761 - val_loss: 0.0830 - learning_rate: 0.0010
# Epoch 16/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step - Precision: 0.9351 - Recall: 0.9288 - accuracy: 0.9339 - loss: 0.1925 - val_Precision: 0.9785 - val_Recall: 0.9773 - val_accuracy: 0.9773 - val_loss: 0.0784 - learning_rate: 0.0010
# Epoch 17/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step - Precision: 0.9421 - Recall: 0.9368 - accuracy: 0.9388 - loss: 0.1876 - val_Precision: 0.9797 - val_Recall: 0.9785 - val_accuracy: 0.9785 - val_loss: 0.0739 - learning_rate: 0.0010
# Epoch 18/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - Precision: 0.9375 - Recall: 0.9312 - accuracy: 0.9350 - loss: 0.1880 - val_Precision: 0.9833 - val_Recall: 0.9821 - val_accuracy: 0.9821 - val_loss: 0.0724 - learning_rate: 0.0010
# Epoch 19/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - Precision: 0.9306 - Recall: 0.9245 - accuracy: 0.9287 - loss: 0.2046 - val_Precision: 0.9833 - val_Recall: 0.9821 - val_accuracy: 0.9821 - val_loss: 0.0675 - learning_rate: 0.0010
# Epoch 20/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step - Precision: 0.9371 - Recall: 0.9302 - accuracy: 0.9338 - loss: 0.2043 - val_Precision: 0.9821 - val_Recall: 0.9809 - val_accuracy: 0.9809 - val_loss: 0.0666 - learning_rate: 0.0010
# Epoch 21/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step - Precision: 0.9380 - Recall: 0.9314 - accuracy: 0.9342 - loss: 0.1852 - val_Precision: 0.9833 - val_Recall: 0.9821 - val_accuracy: 0.9821 - val_loss: 0.0615 - learning_rate: 0.0010
# Epoch 22/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step - Precision: 0.9335 - Recall: 0.9292 - accuracy: 0.9313 - loss: 0.1939 - val_Precision: 0.9856 - val_Recall: 0.9845 - val_accuracy: 0.9845 - val_loss: 0.0617 - learning_rate: 0.0010
# Epoch 23/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step - Precision: 0.9360 - Recall: 0.9304 - accuracy: 0.9339 - loss: 0.1954 - val_Precision: 0.9833 - val_Recall: 0.9821 - val_accuracy: 0.9821 - val_loss: 0.0632 - learning_rate: 0.0010
# Epoch 24/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - Precision: 0.9465 - Recall: 0.9427 - accuracy: 0.9452 - loss: 0.1691 - val_Precision: 0.9844 - val_Recall: 0.9833 - val_accuracy: 0.9845 - val_loss: 0.0632 - learning_rate: 0.0010
# Epoch 25/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - Precision: 0.9489 - Recall: 0.9429 - accuracy: 0.9467 - loss: 0.1497 - val_Precision: 0.9868 - val_Recall: 0.9845 - val_accuracy: 0.9857 - val_loss: 0.0600 - learning_rate: 0.0010
# Epoch 26/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - Precision: 0.9520 - Recall: 0.9480 - accuracy: 0.9510 - loss: 0.1522 - val_Precision: 0.9856 - val_Recall: 0.9845 - val_accuracy: 0.9845 - val_loss: 0.0571 - learning_rate: 0.0010
# Epoch 27/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step - Precision: 0.9439 - Recall: 0.9415 - accuracy: 0.9434 - loss: 0.1701 - val_Precision: 0.9880 - val_Recall: 0.9857 - val_accuracy: 0.9869 - val_loss: 0.0564 - learning_rate: 0.0010
# Epoch 28/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step - Precision: 0.9488 - Recall: 0.9451 - accuracy: 0.9466 - loss: 0.1556 - val_Precision: 0.9845 - val_Recall: 0.9845 - val_accuracy: 0.9845 - val_loss: 0.0568 - learning_rate: 0.0010
# Epoch 29/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step - Precision: 0.9495 - Recall: 0.9456 - accuracy: 0.9486 - loss: 0.1603 - val_Precision: 0.9857 - val_Recall: 0.9857 - val_accuracy: 0.9857 - val_loss: 0.0557 - learning_rate: 0.0010
# Epoch 30/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step - Precision: 0.9497 - Recall: 0.9468 - accuracy: 0.9474 - loss: 0.1686 - val_Precision: 0.9880 - val_Recall: 0.9869 - val_accuracy: 0.9869 - val_loss: 0.0513 - learning_rate: 0.0010
#
# Average test scores across folds:
# Loss: 2.7983 | Accuracy: 0.4589

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Evaluate on Val Data

# %%
# Predict class probabilities
y_val_probs = model.predict(X_val_selected)
# Convert to predicted class labels
y_val_preds = np.argmax(y_val_probs, axis=1)
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step

# %%
print("Test Classification Report:\n")
print(classification_report(y_val, y_val_preds, target_names=genre_label_encoder.classes_))
# Out:
# Test Classification Report:
#
#               precision    recall  f1-score   support
#
#       comedy       0.95      0.98      0.97       324
#  documentary       0.99      0.96      0.98       296
#       horror       0.99      0.98      0.98       427
#
#     accuracy                           0.98      1047
#    macro avg       0.98      0.98      0.98      1047
# weighted avg       0.98      0.98      0.98      1047

# %%
cm = confusion_matrix(y_val, y_val_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=genre_label_encoder.classes_)
disp.plot(cmap='Blues', xticks_rotation=45)
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ## Evaluate on test data

# %%
# Predict class probabilities
y_test_probs = model.predict(X_test_selected)
# Convert to predicted class labels
y_test_preds = np.argmax(y_test_probs, axis=1)
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 209us/step

# %%
print("Test Classification Report:\n")
print(classification_report(y_test, y_test_preds, target_names=genre_label_encoder.classes_))
# Out:
# Test Classification Report:
#
#               precision    recall  f1-score   support
#
#       comedy       0.00      0.00      0.00      1340
#  documentary       0.50      0.83      0.63      1560
#       horror       0.73      0.92      0.82      1212
#
#     accuracy                           0.59      4112
#    macro avg       0.41      0.59      0.48      4112
# weighted avg       0.41      0.59      0.48      4112

# %%
cm = confusion_matrix(y_test, y_test_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=genre_label_encoder.classes_)
disp.plot(cmap='Blues', xticks_rotation=45)
plt.title("Confusion Matrix")
plt.savefig("../plots/nn_extra_features_confusion_matrix.png")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Optional: define class names
class_names = ['comedy', 'documentary', 'horror']

# Plot
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)

plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.savefig('../plots/nn_extra_features_confusion_matrix.png')
plt.show()
