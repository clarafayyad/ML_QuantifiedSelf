# %%
from model_pipeline import model_pipeline
from sklearn.ensemble import RandomForestClassifier
import pandas as pd

# Load your data
df = pd.read_csv("../feature_engineering/data_with_new_features.csv")

# Run the pipeline, prefixing every RF hyperparameter with 'clf__'
results = model_pipeline(
    df,
    model_factory=lambda **p: RandomForestClassifier(
        random_state=42,
        class_weight='balanced',
        **p
    ),
    normalize='global',
    test_val_split=0.1,
    param_distributions={
        'clf__n_estimators': (5, 100, 5),        # IntDistribution
        'clf__max_depth':    [None] + list(range(5, 51, 5)),
        'clf__min_samples_split': (2, 20, 1)        # IntDistribution
    },
    n_trials=20,
    search_cv=3,
    test_participant='clara',
    use_rfe=False
)

print(results['reports']['clara']['f1_weighted'])
# Out:
# c:\Users\kenji\OneDrive\Documenten\ML_QuantifiedSelf\non_temporal_predictions\other_models\model_pipeline.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['genre_encoded'] = genre_le.fit_transform(df['genre'])
# c:\Users\kenji\OneDrive\Documenten\ML_QuantifiedSelf\non_temporal_predictions\other_models\model_pipeline.py:119: ExperimentalWarning: OptunaSearchCV is experimental (supported from v0.17.0). The interface can change in the future.
#   optuna_cv = OptunaSearchCV(
# [I 2025-06-17 15:13:05,869] A new study created in memory with name: no-name-3017d42c-8662-45a6-ab91-57dd2c410feb
# Skipping normalization for constant column: iris_diameter_mm
# Skipping normalization for constant column: td_iris_diameter_mm_mean
# Skipping normalization for constant column: td_iris_diameter_mm_std
# Skipping normalization for constant column: td_iris_diameter_mm_min
# Skipping normalization for constant column: td_iris_diameter_mm_max
# Skipping normalization for constant column: td_iris_diameter_mm_range
# Skipping normalization for constant column: td_iris_diameter_mm_slope
# Skipping normalization for constant column: td_iris_diameter_mm_mean_abs_change
# Skipping normalization for constant column: td_iris_diameter_mm_second_order_diff_mean
# Skipping normalization for constant column: iris_skew
# Skipping normalization for constant column: iris_kurtosis
# Skipping normalization for constant column: heart_rate_fft_dominant_freq
# Skipping normalization for constant column: pupil_diameter_mm_fft_dominant_freq
# Skipping normalization for constant column: iris_diameter_mm_fft_dominant_freq
# Skipping normalization for constant column: pupil_iris_ratio_fft_dominant_freq
#
# --- Testing on clara ---
# [I 2025-06-17 15:13:08,487] Trial 13 finished with value: 1.0 and parameters: {'clf__n_estimators': 5, 'clf__max_depth': 40, 'clf__min_samples_split': 5}. Best is trial 13 with value: 1.0.
# [I 2025-06-17 15:13:08,712] Trial 7 finished with value: 1.0 and parameters: {'clf__n_estimators': 10, 'clf__max_depth': 25, 'clf__min_samples_split': 2}. Best is trial 13 with value: 1.0.
# [I 2025-06-17 15:13:09,762] Trial 9 finished with value: 1.0 and parameters: {'clf__n_estimators': 25, 'clf__max_depth': 15, 'clf__min_samples_split': 3}. Best is trial 13 with value: 1.0.
# [I 2025-06-17 15:13:10,271] Trial 3 finished with value: 1.0 and parameters: {'clf__n_estimators': 35, 'clf__max_depth': 10, 'clf__min_samples_split': 18}. Best is trial 13 with value: 1.0.
# [I 2025-06-17 15:13:10,814] Trial 10 finished with value: 1.0 and parameters: {'clf__n_estimators': 40, 'clf__max_depth': 15, 'clf__min_samples_split': 4}. Best is trial 13 with value: 1.0.
# [I 2025-06-17 15:13:11,040] Trial 14 finished with value: 1.0 and parameters: {'clf__n_estimators': 45, 'clf__max_depth': 40, 'clf__min_samples_split': 19}. Best is trial 13 with value: 1.0.
# [I 2025-06-17 15:13:11,138] Trial 8 finished with value: 1.0 and parameters: {'clf__n_estimators': 45, 'clf__max_depth': 30, 'clf__min_samples_split': 2}. Best is trial 13 with value: 1.0.
# [I 2025-06-17 15:13:11,140] Trial 0 finished with value: 1.0 and parameters: {'clf__n_estimators': 50, 'clf__max_depth': 35, 'clf__min_samples_split': 19}. Best is trial 13 with value: 1.0.
# [I 2025-06-17 15:13:11,280] Trial 15 finished with value: 1.0 and parameters: {'clf__n_estimators': 50, 'clf__max_depth': None, 'clf__min_samples_split': 10}. Best is trial 13 with value: 1.0.
# [I 2025-06-17 15:13:11,298] Trial 1 finished with value: 1.0 and parameters: {'clf__n_estimators': 50, 'clf__max_depth': 30, 'clf__min_samples_split': 10}. Best is trial 13 with value: 1.0.
# [I 2025-06-17 15:13:11,621] Trial 2 finished with value: 1.0 and parameters: {'clf__n_estimators': 60, 'clf__max_depth': 35, 'clf__min_samples_split': 11}. Best is trial 13 with value: 1.0.
# [I 2025-06-17 15:13:11,655] Trial 12 finished with value: 1.0 and parameters: {'clf__n_estimators': 60, 'clf__max_depth': 25, 'clf__min_samples_split': 18}. Best is trial 13 with value: 1.0.
# [I 2025-06-17 15:13:11,899] Trial 16 finished with value: 1.0 and parameters: {'clf__n_estimators': 20, 'clf__max_depth': 50, 'clf__min_samples_split': 15}. Best is trial 13 with value: 1.0.
# [I 2025-06-17 15:13:12,096] Trial 5 finished with value: 1.0 and parameters: {'clf__n_estimators': 75, 'clf__max_depth': 5, 'clf__min_samples_split': 17}. Best is trial 13 with value: 1.0.
# [I 2025-06-17 15:13:12,292] Trial 6 finished with value: 1.0 and parameters: {'clf__n_estimators': 85, 'clf__max_depth': 10, 'clf__min_samples_split': 18}. Best is trial 13 with value: 1.0.
# [I 2025-06-17 15:13:12,313] Trial 4 finished with value: 1.0 and parameters: {'clf__n_estimators': 85, 'clf__max_depth': 35, 'clf__min_samples_split': 20}. Best is trial 13 with value: 1.0.
# [I 2025-06-17 15:13:12,548] Trial 11 finished with value: 1.0 and parameters: {'clf__n_estimators': 100, 'clf__max_depth': 15, 'clf__min_samples_split': 13}. Best is trial 13 with value: 1.0.
# [I 2025-06-17 15:13:12,723] Trial 18 finished with value: 1.0 and parameters: {'clf__n_estimators': 55, 'clf__max_depth': 5, 'clf__min_samples_split': 20}. Best is trial 13 with value: 1.0.
# [I 2025-06-17 15:13:12,776] Trial 17 finished with value: 1.0 and parameters: {'clf__n_estimators': 75, 'clf__max_depth': 5, 'clf__min_samples_split': 7}. Best is trial 13 with value: 1.0.
# [I 2025-06-17 15:13:13,022] Trial 19 finished with value: 1.0 and parameters: {'clf__n_estimators': 85, 'clf__max_depth': 20, 'clf__min_samples_split': 7}. Best is trial 13 with value: 1.0.
# Optuna best params: {'clf__n_estimators': 5, 'clf__max_depth': 40, 'clf__min_samples_split': 5}
#               precision    recall  f1-score   support
#
#       comedy       1.00      1.00      1.00      1336
#  documentary       0.00      0.00      0.00      1556
#       horror       0.44      1.00      0.61      1212
#
#     accuracy                           0.62      4104
#    macro avg       0.48      0.67      0.54      4104
# weighted avg       0.45      0.62      0.51      4104
#
#
# === Avg weighted F1: 0.505 ===
# 0.505400295826109
