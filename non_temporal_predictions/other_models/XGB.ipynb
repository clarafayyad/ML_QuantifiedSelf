# %%
from model_pipeline import model_pipeline
from xgboost import XGBClassifier
import pandas as pd

# Load your data
df = pd.read_csv("../feature_engineering/data_with_new_features.csv")

# Run the pipeline, this time with XGBClassifier under the 'clf' step
results_xgb = model_pipeline(
    df,
    model_factory=lambda **p: XGBClassifier(
        use_label_encoder=False,
        eval_metric='mlogloss',
        random_state=42,
        **p
    ),
    normalize='global',
    test_val_split=0.1,
    param_distributions={
        'clf__n_estimators':        (50, 1000, 50),     # number of trees
        'clf__max_depth':           (3, 15, 1),         # depth per tree
        'clf__learning_rate':       (0.01, 0.3, 0.01),   # shrinkage
        'clf__subsample':           (0.5, 1.0, 0.1),     # row subsampling
        'clf__colsample_bytree':    (0.5, 1.0, 0.1),     # feature subsampling
        'clf__gamma':               (0.0, 5.0, 0.5),     # min loss reduction to split
        'clf__reg_alpha':           (0.0, 5.0, 0.5),     # L1 term on weights
        'clf__reg_lambda':          (0.0, 5.0, 0.5),     # L2 term on weights
    },
    n_trials=20,
    search_cv=3,
    test_participant='clara',
    use_rfe=False
)

print(results_xgb['reports']['clara']['f1_weighted'])
# Out:
# c:\Users\kenji\OneDrive\Documenten\ML_QuantifiedSelf\non_temporal_predictions\other_models\model_pipeline.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['genre_encoded'] = genre_le.fit_transform(df['genre'])
# c:\Users\kenji\OneDrive\Documenten\ML_QuantifiedSelf\non_temporal_predictions\other_models\model_pipeline.py:119: ExperimentalWarning: OptunaSearchCV is experimental (supported from v0.17.0). The interface can change in the future.
#   optuna_cv = OptunaSearchCV(
# [I 2025-06-17 15:15:32,079] A new study created in memory with name: no-name-a165afa0-3214-46cb-95fd-8de3fd2577d7
# Skipping normalization for constant column: iris_diameter_mm
# Skipping normalization for constant column: td_iris_diameter_mm_mean
# Skipping normalization for constant column: td_iris_diameter_mm_std
# Skipping normalization for constant column: td_iris_diameter_mm_min
# Skipping normalization for constant column: td_iris_diameter_mm_max
# Skipping normalization for constant column: td_iris_diameter_mm_range
# Skipping normalization for constant column: td_iris_diameter_mm_slope
# Skipping normalization for constant column: td_iris_diameter_mm_mean_abs_change
# Skipping normalization for constant column: td_iris_diameter_mm_second_order_diff_mean
# Skipping normalization for constant column: iris_skew
# Skipping normalization for constant column: iris_kurtosis
# Skipping normalization for constant column: heart_rate_fft_dominant_freq
# Skipping normalization for constant column: pupil_diameter_mm_fft_dominant_freq
# Skipping normalization for constant column: iris_diameter_mm_fft_dominant_freq
# Skipping normalization for constant column: pupil_iris_ratio_fft_dominant_freq
#
# --- Testing on clara ---
# [I 2025-06-17 15:15:34,597] Trial 14 finished with value: 1.0 and parameters: {'clf__n_estimators': 50, 'clf__max_depth': 5, 'clf__learning_rate': 0.24000000000000002, 'clf__subsample': 0.6, 'clf__colsample_bytree': 0.6, 'clf__gamma': 1.5, 'clf__reg_alpha': 4.5, 'clf__reg_lambda': 1.0}. Best is trial 14 with value: 1.0.
# [I 2025-06-17 15:15:40,115] Trial 9 finished with value: 1.0 and parameters: {'clf__n_estimators': 200, 'clf__max_depth': 10, 'clf__learning_rate': 0.09, 'clf__subsample': 0.8, 'clf__colsample_bytree': 0.8, 'clf__gamma': 4.5, 'clf__reg_alpha': 1.0, 'clf__reg_lambda': 0.0}. Best is trial 14 with value: 1.0.
# [I 2025-06-17 15:15:40,189] Trial 16 finished with value: 1.0 and parameters: {'clf__n_estimators': 150, 'clf__max_depth': 14, 'clf__learning_rate': 0.23, 'clf__subsample': 0.6, 'clf__colsample_bytree': 0.8, 'clf__gamma': 2.0, 'clf__reg_alpha': 1.5, 'clf__reg_lambda': 1.0}. Best is trial 14 with value: 1.0.
# [I 2025-06-17 15:15:41,165] Trial 6 finished with value: 1.0 and parameters: {'clf__n_estimators': 250, 'clf__max_depth': 5, 'clf__learning_rate': 0.23, 'clf__subsample': 0.7, 'clf__colsample_bytree': 1.0, 'clf__gamma': 3.0, 'clf__reg_alpha': 1.0, 'clf__reg_lambda': 0.0}. Best is trial 14 with value: 1.0.
# [I 2025-06-17 15:15:43,308] Trial 15 finished with value: 1.0 and parameters: {'clf__n_estimators': 350, 'clf__max_depth': 10, 'clf__learning_rate': 0.15000000000000002, 'clf__subsample': 1.0, 'clf__colsample_bytree': 0.6, 'clf__gamma': 0.5, 'clf__reg_alpha': 4.0, 'clf__reg_lambda': 2.5}. Best is trial 14 with value: 1.0.
# [I 2025-06-17 15:15:46,623] Trial 8 finished with value: 1.0 and parameters: {'clf__n_estimators': 400, 'clf__max_depth': 9, 'clf__learning_rate': 0.09999999999999999, 'clf__subsample': 0.9, 'clf__colsample_bytree': 0.5, 'clf__gamma': 1.0, 'clf__reg_alpha': 3.0, 'clf__reg_lambda': 3.5}. Best is trial 14 with value: 1.0.
# [I 2025-06-17 15:15:53,681] Trial 7 finished with value: 1.0 and parameters: {'clf__n_estimators': 600, 'clf__max_depth': 13, 'clf__learning_rate': 0.22, 'clf__subsample': 0.6, 'clf__colsample_bytree': 1.0, 'clf__gamma': 1.5, 'clf__reg_alpha': 3.0, 'clf__reg_lambda': 4.0}. Best is trial 14 with value: 1.0.
# [I 2025-06-17 15:15:55,092] Trial 11 finished with value: 1.0 and parameters: {'clf__n_estimators': 600, 'clf__max_depth': 14, 'clf__learning_rate': 0.24000000000000002, 'clf__subsample': 0.7, 'clf__colsample_bytree': 0.5, 'clf__gamma': 0.0, 'clf__reg_alpha': 3.5, 'clf__reg_lambda': 1.0}. Best is trial 14 with value: 1.0.
# [I 2025-06-17 15:15:58,069] Trial 1 finished with value: 1.0 and parameters: {'clf__n_estimators': 700, 'clf__max_depth': 6, 'clf__learning_rate': 0.09999999999999999, 'clf__subsample': 0.5, 'clf__colsample_bytree': 0.7, 'clf__gamma': 3.5, 'clf__reg_alpha': 2.0, 'clf__reg_lambda': 2.0}. Best is trial 14 with value: 1.0.
# [I 2025-06-17 15:15:58,791] Trial 13 finished with value: 1.0 and parameters: {'clf__n_estimators': 750, 'clf__max_depth': 11, 'clf__learning_rate': 0.05, 'clf__subsample': 1.0, 'clf__colsample_bytree': 0.6, 'clf__gamma': 2.0, 'clf__reg_alpha': 4.0, 'clf__reg_lambda': 3.0}. Best is trial 14 with value: 1.0.
# [I 2025-06-17 15:15:59,313] Trial 12 finished with value: 1.0 and parameters: {'clf__n_estimators': 750, 'clf__max_depth': 15, 'clf__learning_rate': 0.18000000000000002, 'clf__subsample': 0.6, 'clf__colsample_bytree': 0.7, 'clf__gamma': 1.0, 'clf__reg_alpha': 1.0, 'clf__reg_lambda': 4.5}. Best is trial 14 with value: 1.0.
# [I 2025-06-17 15:16:00,812] Trial 3 finished with value: 1.0 and parameters: {'clf__n_estimators': 800, 'clf__max_depth': 9, 'clf__learning_rate': 0.06999999999999999, 'clf__subsample': 0.7, 'clf__colsample_bytree': 0.7, 'clf__gamma': 4.5, 'clf__reg_alpha': 5.0, 'clf__reg_lambda': 5.0}. Best is trial 14 with value: 1.0.
# [I 2025-06-17 15:16:03,514] Trial 4 finished with value: 1.0 and parameters: {'clf__n_estimators': 1000, 'clf__max_depth': 8, 'clf__learning_rate': 0.12, 'clf__subsample': 0.9, 'clf__colsample_bytree': 0.7, 'clf__gamma': 3.5, 'clf__reg_alpha': 1.5, 'clf__reg_lambda': 5.0}. Best is trial 14 with value: 1.0.
# [I 2025-06-17 15:16:03,539] Trial 5 finished with value: 1.0 and parameters: {'clf__n_estimators': 1000, 'clf__max_depth': 10, 'clf__learning_rate': 0.21000000000000002, 'clf__subsample': 0.5, 'clf__colsample_bytree': 0.9, 'clf__gamma': 4.0, 'clf__reg_alpha': 3.5, 'clf__reg_lambda': 4.5}. Best is trial 14 with value: 1.0.
# [I 2025-06-17 15:16:03,924] Trial 19 finished with value: 1.0 and parameters: {'clf__n_estimators': 750, 'clf__max_depth': 12, 'clf__learning_rate': 0.19, 'clf__subsample': 0.6, 'clf__colsample_bytree': 0.7, 'clf__gamma': 1.5, 'clf__reg_alpha': 1.5, 'clf__reg_lambda': 3.5}. Best is trial 14 with value: 1.0.
# [I 2025-06-17 15:16:04,062] Trial 17 finished with value: 1.0 and parameters: {'clf__n_estimators': 800, 'clf__max_depth': 7, 'clf__learning_rate': 0.25, 'clf__subsample': 0.8, 'clf__colsample_bytree': 0.6, 'clf__gamma': 0.5, 'clf__reg_alpha': 1.5, 'clf__reg_lambda': 1.5}. Best is trial 14 with value: 1.0.
# [I 2025-06-17 15:16:04,384] Trial 2 finished with value: 1.0 and parameters: {'clf__n_estimators': 950, 'clf__max_depth': 14, 'clf__learning_rate': 0.02, 'clf__subsample': 0.5, 'clf__colsample_bytree': 0.7, 'clf__gamma': 3.5, 'clf__reg_alpha': 1.0, 'clf__reg_lambda': 2.5}. Best is trial 14 with value: 1.0.
# [I 2025-06-17 15:16:04,737] Trial 18 finished with value: 1.0 and parameters: {'clf__n_estimators': 800, 'clf__max_depth': 10, 'clf__learning_rate': 0.22, 'clf__subsample': 0.7, 'clf__colsample_bytree': 0.7, 'clf__gamma': 0.0, 'clf__reg_alpha': 2.5, 'clf__reg_lambda': 4.5}. Best is trial 14 with value: 1.0.
# [I 2025-06-17 15:16:05,112] Trial 0 finished with value: 1.0 and parameters: {'clf__n_estimators': 850, 'clf__max_depth': 8, 'clf__learning_rate': 0.01, 'clf__subsample': 0.5, 'clf__colsample_bytree': 0.8, 'clf__gamma': 0.5, 'clf__reg_alpha': 4.5, 'clf__reg_lambda': 0.5}. Best is trial 14 with value: 1.0.
# [I 2025-06-17 15:16:05,267] Trial 10 finished with value: 1.0 and parameters: {'clf__n_estimators': 1000, 'clf__max_depth': 5, 'clf__learning_rate': 0.01, 'clf__subsample': 1.0, 'clf__colsample_bytree': 0.9, 'clf__gamma': 2.5, 'clf__reg_alpha': 5.0, 'clf__reg_lambda': 2.5}. Best is trial 14 with value: 1.0.
# c:\Users\kenji\OneDrive\Documenten\ML_QuantifiedSelf\.venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:16:05] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Optuna best params: {'clf__n_estimators': 50, 'clf__max_depth': 5, 'clf__learning_rate': 0.24000000000000002, 'clf__subsample': 0.6, 'clf__colsample_bytree': 0.6, 'clf__gamma': 1.5, 'clf__reg_alpha': 4.5, 'clf__reg_lambda': 1.0}
#               precision    recall  f1-score   support
#
#       comedy       0.00      0.00      0.00      1336
#  documentary       0.00      0.00      0.00      1556
#       horror       0.30      1.00      0.46      1212
#
#     accuracy                           0.30      4104
#    macro avg       0.10      0.33      0.15      4104
# weighted avg       0.09      0.30      0.13      4104
#
#
# === Avg weighted F1: 0.135 ===
# 0.1346613335445461
